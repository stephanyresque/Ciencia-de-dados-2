# %% [markdown]
# <a href="https://colab.research.google.com/github/stephanyresque/Ciencia-de-dados-2/blob/main/18_19_11_24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme(style='dark', palette='bright', context='notebook')

ARQUIVO_DADOS = 'churn_clientes.csv'

df = pd.read_csv(ARQUIVO_DADOS)
df = df.drop(columns='id_cliente', axis=1)


colunas_numericas = df.select_dtypes(include='number').columns
colunas_categoricas = df.select_dtypes(exclude='number').columns
colunas_categoricas = colunas_categoricas.drop('churn')

df.head()
# Out:
#       genero idoso tem_parceiro tem_dependentes  meses_na_empresa  \
# 0   Feminino   Não          Sim             Não                 1
# 1  Masculino   Não          Não             Não                34
# 2  Masculino   Não          Não             Não                 2
# 3  Masculino   Não          Não             Não                45
# 4   Feminino   Não          Não             Não                 2
#
#   servico_telefone multiplas_linhas servico_internet servico_seguranca  \
# 0              Não              Não              DSL               Não
# 1              Sim              Não              DSL               Sim
# 2              Sim              Não              DSL               Sim
# 3              Não              Não              DSL               Sim
# 4              Sim              Não     Fibra optica               Não
#
#   servico_backup servico_protecao_equipamento servico_suporte_tecnico  \
# ...

# %%
g = sns.FacetGrid(df, col = 'contrato')
g.map_dataframe(sns.histplot, x = 'meses_na_empresa');

# %%
g = sns.FacetGrid(df, col = 'contrato')
g.map_dataframe(sns.histplot, x = 'meses_na_empresa')
plt.show()

# %%
g = sns.FacetGrid(df, col = 'contrato', hue = 'churn')
g.map_dataframe(sns.histplot, x = 'meses_na_empresa')
plt.show()

# %%
g = sns.FacetGrid(df, col = 'contrato', row = 'churn')
g.map_dataframe(sns.histplot, x = 'meses_na_empresa')
plt.show()

# %%
g = sns.FacetGrid(df, col = 'contrato', row = 'churn')
g.map_dataframe(sns.kdeplot, x = 'meses_na_empresa')
plt.show()

# %%
g = sns.FacetGrid(df, col = 'contrato', row = 'churn')
g.map_dataframe(sns.scatterplot, x = 'valor_mensal', y = 'total_gasto')
plt.show()

# %%
g = sns.FacetGrid(df, col = 'contrato', hue = 'churn')
g.map_dataframe(sns.scatterplot, x = 'valor_mensal', y = 'total_gasto')
g.add_legend()
plt.show()

# %%
sns.pairplot(data = df, hue = 'churn')
plt.show()

# %%
sns.pairplot(data = df, hue = 'churn', diag_kind='hist')
plt.show()

# %%
fig, axs = plt.subplots(nrows=1, ncols = 3, figsize = (14, 6), tight_layout = True)

for i, coluna in enumerate(colunas_numericas):
    sns.boxplot(data = df, x = coluna, ax = axs[i])

plt.show()

# %%
fig, axs = plt.subplots(nrows=1, ncols = 3, figsize = (14, 6), tight_layout = True)

for i, coluna in enumerate(colunas_numericas):
    sns.boxplot(data = df, y = coluna, ax = axs[i])

plt.show()

# %%
fig, axs = plt.subplots(nrows=1, ncols = 3, figsize = (16, 4), tight_layout = True, sharey=True)

for i, coluna in enumerate(colunas_numericas):
    sns.boxplot(data = df, x = coluna, y = 'churn',ax = axs[i], hue = 'churn')

plt.show()

# %%
fig, axs = plt.subplots(nrows=1, ncols = 3, figsize = (16, 6), tight_layout = True)

for i, coluna in enumerate(colunas_numericas):
    sns.boxplot(data = df, y = coluna, x = 'churn',ax = axs[i], hue = 'churn')

plt.show()

# %%
colunas_categoricas, len(colunas_categoricas)
# Out:
# (Index(['genero', 'idoso', 'tem_parceiro', 'tem_dependentes',
#         'servico_telefone', 'multiplas_linhas', 'servico_internet',
#         'servico_seguranca', 'servico_backup', 'servico_protecao_equipamento',
#         'servico_suporte_tecnico', 'streaming_tv', 'streaming_filmes',
#         'contrato', 'fatura_digital', 'forma_pagamento'],
#        dtype='object'),
#  16)

# %%
fig, axs = plt.subplots(nrows = 4, ncols = 4, figsize = (14, 14))

plt.show()

# %%
print(list(axs.flat))
# Out:
# [<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >]

# %%
fig, axs = plt.subplots(nrows = 4, ncols = 4, figsize = (14, 14))

for i, coluna in enumerate(colunas_categoricas):
    sns.histplot(data = df, x = coluna, hue = 'churn',multiple = 'fill', ax = axs.flat[i])

plt.show()

# %%
fig, axs = plt.subplots(nrows = 4, ncols = 4, figsize = (14, 14), sharey = True, tight_layout = True)

for i, coluna in enumerate(colunas_categoricas):
    h = sns.histplot(data = df, x = coluna, hue = 'churn',multiple = 'fill', ax = axs.flat[i], stat = 'percent', shrink = 0.8)
    h.tick_params(axis='x', rotation=45)
    legenda = h.get_legend()
    legenda.remove()

rotulos = [text.get_text() for text in legenda.get_texts()]
fig.legend(handles = legenda.legend_handles, labels = rotulos, loc = 'upper center', ncols = 2, title = 'churn', bbox_to_anchor = (0.5, 0.965))
fig.suptitle('Churn por variável categórica\n\n', fontsize = 16)
fig.align_labels()
plt.show()

# %%
from matplotlib.ticker import PercentFormatter

fig, axs = plt.subplots(nrows = 4, ncols = 4, figsize = (14, 16), sharey = True)

for i, coluna in enumerate(colunas_categoricas):
    h = sns.histplot(data = df, x = coluna, hue = 'churn',multiple = 'fill', ax = axs.flat[i], stat = 'percent', shrink = 0.8)
    h.tick_params(axis='x', rotation=45)
    h.grid(False)
    h.yaxis.set_major_formatter(PercentFormatter(1))
    h.set_ylabel('')

    for barra in h.containers:
      h.bar_label(barra, label_type = 'center', labels = [f'{parte.get_height():.1%}'for parte in barra], color = 'white', weight = 'bold', fontsize = 10)

    legenda = h.get_legend()
    legenda.remove()

rotulos = [text.get_text() for text in legenda.get_texts()]

fig.legend(handles = legenda.legend_handles, labels = rotulos, loc = 'upper center', ncols = 2, title = 'churn', bbox_to_anchor = (0.5, 0.965))
fig.suptitle('Churn por variável categórica\n\n', fontsize = 16)
fig.align_labels()

plt.subplots_adjust(wspace = 0.4, hspace = 0.5, top = 0.9)
plt.show()

# %%
sns.boxplot(x = 'servico_internet', y = 'valor_mensal', data = df)
plt.show()

# %%
sns.boxplot(x = 'servico_internet', y = 'valor_mensal', data = df, hue = 'churn')
plt.show()
