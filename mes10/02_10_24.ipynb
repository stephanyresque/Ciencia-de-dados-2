# %% [markdown]
# <a href="https://colab.research.google.com/github/stephanyresque/Ciencia-de-dados-2/blob/main/02_10_24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_excel('reshaping.xlsx')

# %%
df
# Out:
#    Estudante Categoria  Semana          Tópico  Nota
# 0      Maria    Testes       1       1. Python   100
# 1      Maria   Projeto       1       1. Python   100
# 2      Maria    Testes       1       2. GitHub    70
# 3      Maria   Projeto       1       2. GitHub    70
# 4      Maria    Testes       2   3. Matplotlib    80
# 5      Maria   Projeto       2   3. Matplotlib    70
# 6      Maria    Testes       2          4. SQL    80
# 7      Maria   Projeto       2          4. SQL    70
# 8      Maria    Testes       3        5. NumPy    60
# 9      Maria   Projeto       3        5. NumPy    60
# 10     Maria    Testes       3          6. POO    90
# 11     Maria   Projeto       3          6. POO    80
# 12     Maria    Testes       4       7. Pandas    70
# 13     Maria   Projeto       4       7. Pandas    70
# 14     Maria    Testes       4  8. Estatística    80
# 15     Maria   Projeto       4  8. Estatística    80
# 16      João    Testes       1       1. Python   100
# ...

# %%
#pivot -> operação que reorganiza os dados de um dataframe, alterando a forma dos dados

# %% [markdown]
# ![Captura de tela 2024-10-02 135804.png](data:image/png;base64,...)

# %%
df_pivo = df.pivot(
    index = ['Estudante'],
    columns = ['Categoria', 'Semana', 'Tópico'],
    values = ['Nota']
)

# %%
df_pivo
# Out:
#                Nota                                                            \
# Categoria    Testes   Projeto    Testes   Projeto        Testes       Projeto
# Semana            1         1         1         1             2             2
# Tópico    1. Python 1. Python 2. GitHub 2. GitHub 3. Matplotlib 3. Matplotlib
# Estudante
# João            100        80        90        90            60            70
# Maria           100       100        70        70            80            70
#
#                                                                                \
# Categoria Testes Projeto   Testes  Projeto Testes Projeto    Testes   Projeto
# Semana         2       2        3        3      3       3         4         4
# Tópico    4. SQL  4. SQL 5. NumPy 5. NumPy 6. POO  6. POO 7. Pandas 7. Pandas
# Estudante
# João          70      80       80       90     70      80        70       100
# Maria         80      70       60       60     90      80        70        70
#
#
# ...

# %%
df_pivo.index
# Out:
# Index(['João', 'Maria'], dtype='object', name='Estudante')

# %%
df_pivo.columns
# Out:
# MultiIndex([('Nota',  'Testes', 1,      '1. Python'),
#             ('Nota', 'Projeto', 1,      '1. Python'),
#             ('Nota',  'Testes', 1,      '2. GitHub'),
#             ('Nota', 'Projeto', 1,      '2. GitHub'),
#             ('Nota',  'Testes', 2,  '3. Matplotlib'),
#             ('Nota', 'Projeto', 2,  '3. Matplotlib'),
#             ('Nota',  'Testes', 2,         '4. SQL'),
#             ('Nota', 'Projeto', 2,         '4. SQL'),
#             ('Nota',  'Testes', 3,       '5. NumPy'),
#             ('Nota', 'Projeto', 3,       '5. NumPy'),
#             ('Nota',  'Testes', 3,         '6. POO'),
#             ('Nota', 'Projeto', 3,         '6. POO'),
#             ('Nota',  'Testes', 4,      '7. Pandas'),
#             ('Nota', 'Projeto', 4,      '7. Pandas'),
#             ('Nota',  'Testes', 4, '8. Estatística'),
#             ('Nota', 'Projeto', 4, '8. Estatística')],
#            names=[None, 'Categoria', 'Semana', 'Tópico'])

# %%
df_pivo.stack()
# Out:
# <ipython-input-10-c194fc8a3085>:1: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   df_pivo.stack()
#                            Nota                                               \
# Categoria                Testes Projeto Testes Projeto Testes Projeto Testes
# Semana                        1       1      2       2      3       3      4
# Estudante Tópico
# João      1. Python       100.0    80.0    NaN     NaN    NaN     NaN    NaN
#           2. GitHub        90.0    90.0    NaN     NaN    NaN     NaN    NaN
#           3. Matplotlib     NaN     NaN   60.0    70.0    NaN     NaN    NaN
#           4. SQL            NaN     NaN   70.0    80.0    NaN     NaN    NaN
#           5. NumPy          NaN     NaN    NaN     NaN   80.0    90.0    NaN
# ...

# %%
df_pivo.stack(level = 1)
# Out:
# <ipython-input-12-0c5fa176d18c>:1: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   df_pivo.stack(level = 1)
#                          Nota                                                 \
# Semana                      1                       2               3
# Tópico              1. Python 2. GitHub 3. Matplotlib 4. SQL 5. NumPy 6. POO
# Estudante Categoria
# João      Projeto          80        90            70     80       90     80
#           Testes          100        90            60     70       80     70
# Maria     Projeto         100        70            70     70       60     80
#           Testes          100        70            80     80       60     90
#
#
# Semana                      4
# Tópico              7. Pandas 8. Estatística
# Estudante Categoria
# ...

# %%
df_pivo.stack(level = 1).index
# Out:
# <ipython-input-13-eefc91ee2394>:1: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   df_pivo.stack(level = 1).index
# MultiIndex([( 'João', 'Projeto'),
#             ( 'João',  'Testes'),
#             ('Maria', 'Projeto'),
#             ('Maria',  'Testes')],
#            names=['Estudante', 'Categoria'])

# %%
df_pivo.stack(level = 1).unstack()
# Out:
# <ipython-input-14-d549bf7c6964>:1: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   df_pivo.stack(level = 1).unstack()
#                Nota                                                       \
# Semana            1                                     2
# Tópico    1. Python        2. GitHub        3. Matplotlib         4. SQL
# Categoria   Projeto Testes   Projeto Testes       Projeto Testes Projeto
# Estudante
# João             80    100        90     90            70     60      80
# Maria           100    100        70     70            70     80      70
#
#                                                                   \
# Semana                  3                               4
# Tópico           5. NumPy         6. POO        7. Pandas
# ...

# %%
df_pivo.stack(level = 1).unstack(level = 0)
# Out:
# <ipython-input-16-35a2976f4249>:1: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   df_pivo.stack(level = 1).unstack(level = 0)
#                Nota                                                         \
# Semana            1                                   2
# Tópico    1. Python       2. GitHub       3. Matplotlib       4. SQL
# Estudante      João Maria      João Maria          João Maria   João Maria
# Categoria
# Projeto          80   100        90    70            70    70     80    70
# Testes          100   100        90    70            60    80     70    80
#
#
# Semana           3                            4
# Tópico    5. NumPy       6. POO       7. Pandas       8. Estatística
# Estudante     João Maria   João Maria      João Maria           João Maria
# ...

# %%
df_pivo
# Out:
#                Nota                                                            \
# Categoria    Testes   Projeto    Testes   Projeto        Testes       Projeto
# Semana            1         1         1         1             2             2
# Tópico    1. Python 1. Python 2. GitHub 2. GitHub 3. Matplotlib 3. Matplotlib
# Estudante
# João            100        80        90        90            60            70
# Maria           100       100        70        70            80            70
#
#                                                                                \
# Categoria Testes Projeto   Testes  Projeto Testes Projeto    Testes   Projeto
# Semana         2       2        3        3      3       3         4         4
# Tópico    4. SQL  4. SQL 5. NumPy 5. NumPy 6. POO  6. POO 7. Pandas 7. Pandas
# Estudante
# João          70      80       80       90     70      80        70       100
# Maria         80      70       60       60     90      80        70        70
#
#
# ...

# %%
df_pivo = df.pivot(
    index = ['Estudante', 'Categoria', 'Semana'],
    columns = ['Tópico'],
    values = ['Nota']
)

# %%
df_pivo
# Out:
#                                 Nota                                          \
# Tópico                     1. Python 2. GitHub 3. Matplotlib 4. SQL 5. NumPy
# Estudante Categoria Semana
# João      Projeto   1           80.0      90.0           NaN    NaN      NaN
#                     2            NaN       NaN          70.0   80.0      NaN
#                     3            NaN       NaN           NaN    NaN     90.0
#                     4            NaN       NaN           NaN    NaN      NaN
#           Testes    1          100.0      90.0           NaN    NaN      NaN
#                     2            NaN       NaN          60.0   70.0      NaN
#                     3            NaN       NaN           NaN    NaN     80.0
#                     4            NaN       NaN           NaN    NaN      NaN
# Maria     Projeto   1          100.0      70.0           NaN    NaN      NaN
#                     2            NaN       NaN          70.0   70.0      NaN
# ...
