# %% [markdown]
# <a href="https://colab.research.google.com/github/stephanyresque/Ciencia-de-dados-2/blob/main/13_11_24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

ARQUIVO_DADOS = 'churn_clientes.csv'

df = pd.read_csv(ARQUIVO_DADOS)
df = df.drop(columns='id_cliente', axis=1)


colunas_numericas = df.select_dtypes(include='number').columns
colunas_categoricas = df.select_dtypes(exclude='number').columns
colunas_categoricas = colunas_categoricas.drop('churn')

df.head()
# Out:
#       genero idoso tem_parceiro tem_dependentes  meses_na_empresa  \
# 0   Feminino   Não          Sim             Não                 1
# 1  Masculino   Não          Não             Não                34
# 2  Masculino   Não          Não             Não                 2
# 3  Masculino   Não          Não             Não                45
# 4   Feminino   Não          Não             Não                 2
#
#   servico_telefone multiplas_linhas servico_internet servico_seguranca  \
# 0              Não              Não              DSL               Não
# 1              Sim              Não              DSL               Sim
# 2              Sim              Não              DSL               Sim
# 3              Não              Não              DSL               Sim
# 4              Sim              Não     Fibra optica               Não
#
#   servico_backup servico_protecao_equipamento servico_suporte_tecnico  \
# 0            Sim                          Não                     Não
# 1            Não                          Sim                     Não
# 2            Sim                          Não                     Não
# 3            Não                          Sim                     Sim
# 4            Não                          Não                     Não
#
#   streaming_tv streaming_filmes contrato fatura_digital forma_pagamento  \
# 0          Não              Não   Mensal            Sim          Boleto
# 1          Não              Não    Anual            Não          Cheque
# 2          Não              Não   Mensal            Sim          Cheque
# 3          Não              Não    Anual            Não   Transferencia
# 4          Não              Não   Mensal            Sim          Boleto
#
#    valor_mensal  total_gasto churn
# 0         29.85        29.85   Não
# 1         56.95      1889.50   Não
# 2         53.85       108.15   Sim
# 3         42.30      1840.75   Não
# 4         70.70       151.65   Sim

# %%
df[colunas_numericas].hist(layout=(1,3), figsize = (14,6));

# %%
df['meses_na_empresa'].value_counts(bins = 10).sort_index()
# Out:
# (-0.073, 7.2]    1612
# (7.2, 14.4]       759
# (14.4, 21.6]      570
# (21.6, 28.8]      556
# (28.8, 36.0]      545
# (36.0, 43.2]      444
# (43.2, 50.4]      452
# (50.4, 57.6]      495
# (57.6, 64.8]      501
# (64.8, 72.0]     1109
# Name: count, dtype: int64

# %%
df['valor_mensal'].value_counts(bins = 10).sort_index()
# Out:
# (18.148999999999997, 28.3]    1606
# (28.3, 38.35]                  191
# (38.35, 48.4]                  365
# (48.4, 58.45]                  640
# (58.45, 68.5]                  474
# (68.5, 78.55]                  893
# (78.55, 88.6]                  953
# (88.6, 98.65]                  873
# (98.65, 108.7]                 754
# (108.7, 118.75]                294
# Name: count, dtype: int64

# %%
df['total_gasto'].value_counts(bins = 10).sort_index()
# Out:
# (10.133000000000001, 885.4]    2709
# (885.4, 1752.0]                1239
# (1752.0, 2618.6]                671
# (2618.6, 3485.2]                508
# (3485.2, 4351.8]                454
# (4351.8, 5218.4]                412
# (5218.4, 6085.0]                395
# (6085.0, 6951.6]                310
# (6951.6, 7818.2]                223
# (7818.2, 8684.8]                122
# Name: count, dtype: int64

# %%
sns.set_theme(style = 'dark', palette='bright', context = 'notebook')

sns.histplot(x = 'meses_na_empresa', data = df, hue = 'contrato');

# %%
sns.histplot(x = 'meses_na_empresa', data = df, hue = 'contrato', multiple = 'stack');

# %%
fig, axs = plt.subplots(nrows = 1, ncols = 3, figsize = (14,6))

for i, coluna in enumerate(colunas_numericas):
    sns.histplot(x = coluna, data = df, ax = axs[i], hue = 'contrato', multiple = 'stack')

plt.show()
