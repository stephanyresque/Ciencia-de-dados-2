# %% [markdown]
# <a href="https://colab.research.google.com/github/stephanyresque/Ciencia-de-dados-2/blob/main/12_11_24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
meses = ['Jan', 'Fev', 'Mar', 'Abr', 'Mai', 'Jun', 'Jul', 'Ago', 'Set', 'Out', 'Nov', 'Dez']
vendas = [85, 90, 78, 92, 88, 96, 94, 98, 100, 102, 105, 108]

# %%
import seaborn as sns

# %%
sns.lineplot(x=meses, y=vendas);

# %%
dados = {'Meses': meses, 'Vendas': vendas}

sns.lineplot(x = 'Meses', y = 'Vendas', data = dados)
# Out:
# <Axes: xlabel='Meses', ylabel='Vendas'>

# %%
linha = sns.lineplot(x = 'Meses', y = 'Vendas', data = dados)

print(type(linha))
# Out:
# <class 'matplotlib.axes._axes.Axes'>

# %%
linha = sns.lineplot(x = 'Meses', y = 'Vendas', data = dados);

linha.set_title('Vendas Mensais');

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize = (10, 6))

sns.lineplot(x = 'Meses', y = 'Vendas', data = dados, ax = ax)

ax.set_title('Vendas Mensais');

plt.show()

# %%
cidades = ['Brasília', 'Rio de Janeiro', 'São Paulo', 'Curitiba', 'Manaus']
temperaturas = [27, 29, 25, 23, 31]

barras = sns.barplot(x = cidades, y = temperaturas);

barras.set_title('Temperaturas Médias');
barras.set_xlabel('Cidades');
barras.set_ylabel('Temperatura (ºC)');

# %%
dados_2 = {'Cidades': cidades, 'Temperaturas': temperaturas}

barras = sns.barplot(x = 'Cidades', y = 'Temperaturas', data = dados_2);

barras.set_title('Temperaturas Médias');

# %%
import seaborn as sns

meses = ['Jan', 'Fev', 'Mar', 'Abr', 'Mai', 'Jun', 'Jul', 'Ago', 'Set', 'Out', 'Nov', 'Dez']
vendas = [85, 90, 78, 92, 88, 96, 94, 98, 100, 102, 105, 108]

dados = {'Meses': meses, 'Vendas': vendas}

sns.lineplot(x='Meses', y='Vendas', data=dados);

# %%
estilos = ['darkgrid', 'whitegrid', 'dark', 'white', 'ticks']
contextos = ['paper', 'notebook', 'talk', 'poster']
paletas = ['deep', 'muted', 'bright', 'pastel', 'dark', 'colorblind']

# %%
sns.set_theme() #padrão é darkgrid

sns.lineplot(x='Meses', y='Vendas', data=dados);

# %%
sns.set_theme(style = 'darkgrid')

sns.lineplot(x='Meses', y='Vendas', data=dados);

# %%
sns.set_theme(style = 'whitegrid')

sns.lineplot(x='Meses', y='Vendas', data=dados);

# %%
sns.set_theme(style = 'dark')

sns.lineplot(x='Meses', y='Vendas', data=dados);

# %%
sns.set_theme(style = 'ticks')

sns.lineplot(x='Meses', y='Vendas', data=dados);

# %%
sns.set_theme(style = 'darkgrid', context = 'notebook')

sns.lineplot(x='Meses', y='Vendas', data=dados);

# %%
sns.set_theme(style = 'darkgrid', context = 'paper')

sns.lineplot(x='Meses', y='Vendas', data=dados);

# %%
sns.set_theme(style = 'darkgrid', context = 'talk')

sns.lineplot(x='Meses', y='Vendas', data=dados);

# %%
sns.set_theme(style = 'darkgrid', context = 'poster')

sns.lineplot(x='Meses', y='Vendas', data=dados);

# %%
sns.set_theme(style = 'darkgrid', context = 'notebook', palette='Pastel2')

sns.lineplot(x='Meses', y='Vendas', data=dados);

# %%
sns.set_theme(style = 'darkgrid', context = 'notebook', palette='muted')

sns.lineplot(x='Meses', y='Vendas', data=dados);

# %%
dados_2 = {'Cidades': cidades, 'Temperaturas': temperaturas}
sns.set_theme(style = 'white',palette = 'colorblind', context = 'talk')
barras = sns.barplot(x = 'Cidades', y = 'Temperaturas', data = dados_2);

barras.set_title('Temperaturas Médias');

# %%
import pandas as pd

BASE = 'churn_clientes.csv'

# %%
df = pd.read_csv(BASE)

df.head()
# Out:
#    id_cliente     genero idoso tem_parceiro tem_dependentes  meses_na_empresa  \
# 0  7590-VHVEG   Feminino   Não          Sim             Não                 1
# 1  5575-GNVDE  Masculino   Não          Não             Não                34
# 2  3668-QPYBK  Masculino   Não          Não             Não                 2
# 3  7795-CFOCW  Masculino   Não          Não             Não                45
# 4  9237-HQITU   Feminino   Não          Não             Não                 2
#
#   servico_telefone multiplas_linhas servico_internet servico_seguranca  ...  \
# 0              Não              Não              DSL               Não  ...
# 1              Sim              Não              DSL               Sim  ...
# 2              Sim              Não              DSL               Sim  ...
# 3              Não              Não              DSL               Sim  ...
# 4              Sim              Não     Fibra optica               Não  ...
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   id_cliente                    7043 non-null   object
#  1   genero                        7043 non-null   object
#  2   idoso                         7043 non-null   object
#  3   tem_parceiro                  7043 non-null   object
#  4   tem_dependentes               7043 non-null   object
#  5   meses_na_empresa              7043 non-null   int64
#  6   servico_telefone              7043 non-null   object
#  7   multiplas_linhas              7043 non-null   object
#  8   servico_internet              7043 non-null   object
#  9   servico_seguranca             7043 non-null   object
#  10  servico_backup                7043 non-null   object
#  11  servico_protecao_equipamento  7043 non-null   object
# ...

# %%
df.describe()
# Out:
#        meses_na_empresa  valor_mensal  total_gasto
# count       7043.000000   7043.000000  7043.000000
# mean          32.371149     64.761692  2281.916928
# std           24.559481     30.090047  2265.270398
# min            0.000000     18.250000    18.800000
# 25%            9.000000     35.500000   402.225000
# 50%           29.000000     70.350000  1397.475000
# 75%           55.000000     89.850000  3786.600000
# max           72.000000    118.750000  8684.800000

# %%
df.describe(exclude = 'number')
# Out:
#         id_cliente     genero idoso tem_parceiro tem_dependentes  \
# count         7043       7043  7043         7043            7043
# unique        7043          2     2            2               2
# top     7590-VHVEG  Masculino   Não          Não             Não
# freq             1       3555  5901         3641            4933
#
#        servico_telefone multiplas_linhas servico_internet servico_seguranca  \
# count              7043             7043             7043              7043
# unique                2                2                3                 2
# top                 Sim              Não     Fibra optica               Não
# freq               6361             4072             3096              5024
#
#        servico_backup servico_protecao_equipamento servico_suporte_tecnico  \
# count            7043                         7043                    7043
# unique              2                            2                       2
# ...

# %%
df['churn'].value_counts(normalize = True) * 100
# Out:
# churn
# Não    73.463013
# Sim    26.536987
# Name: proportion, dtype: float64

# %%
df = df.drop(['id_cliente'], axis = 1)

# %%
df.head()
# Out:
#       genero idoso tem_parceiro tem_dependentes  meses_na_empresa  \
# 0   Feminino   Não          Sim             Não                 1
# 1  Masculino   Não          Não             Não                34
# 2  Masculino   Não          Não             Não                 2
# 3  Masculino   Não          Não             Não                45
# 4   Feminino   Não          Não             Não                 2
#
#   servico_telefone multiplas_linhas servico_internet servico_seguranca  \
# 0              Não              Não              DSL               Não
# 1              Sim              Não              DSL               Sim
# 2              Sim              Não              DSL               Sim
# 3              Não              Não              DSL               Sim
# 4              Sim              Não     Fibra optica               Não
#
#   servico_backup servico_protecao_equipamento servico_suporte_tecnico  \
# ...

# %%
colunas_numericas = df.select_dtypes(include = 'number').columns
colunas_categoricas = df.select_dtypes(exclude = 'number').columns

# %%
colunas_categoricas = colunas_categoricas.drop(['churn']) #variável dependente
