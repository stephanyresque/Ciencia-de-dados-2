# %% [markdown]
# <a href="https://colab.research.google.com/github/stephanyresque/Ciencia-de-dados-2/blob/main/20_11_24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
empresas = {
    "Exxon Mobil": 1,
    "JP Morgan Chase": 1,
    "General Electric": 1,
    "Royal Dutch Shell": 2,
    "ICBC": 3,
    "HSBC Holdings": 4,
    "PetroChina": 3,
    "Berkshire Hathaway": 1,
    "Wells Fargo": 1,
    "Petrobras": 5,
}

paises = {
    1: "Estados Unidos",
    2: "Holanda",
    3: "China",
    4: "Reino Unido",
    5: "Brasil",
}

# %%
df_empresas = pd.DataFrame(empresas.items(), columns = ['empresa', 'codigo_pais'])

df_empresas
# Out:
#               empresa  codigo_pais
# 0         Exxon Mobil            1
# 1     JP Morgan Chase            1
# 2    General Electric            1
# 3   Royal Dutch Shell            2
# 4                ICBC            3
# 5       HSBC Holdings            4
# 6          PetroChina            3
# 7  Berkshire Hathaway            1
# 8         Wells Fargo            1
# 9           Petrobras            5

# %%
df_empresas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   empresa      10 non-null     object
#  1   codigo_pais  10 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 288.0+ bytes

# %%
df_empresas.describe() #não faz sentido o describe nesse sentido -> variável qualitativa nominal
# Out:
#        codigo_pais
# count     10.00000
# mean       2.20000
# std        1.47573
# min        1.00000
# 25%        1.00000
# 50%        1.50000
# 75%        3.00000
# max        5.00000

# %%
df_empresas['codigo_pais'].value_counts() #isso faz sentido
# Out:
# codigo_pais
# 1    5
# 3    2
# 2    1
# 4    1
# 5    1
# Name: count, dtype: int64

# %%
df_empresas['codigo_pais'] = df_empresas['codigo_pais'].astype('category')

df_empresas
# Out:
#               empresa codigo_pais
# 0         Exxon Mobil           1
# 1     JP Morgan Chase           1
# 2    General Electric           1
# 3   Royal Dutch Shell           2
# 4                ICBC           3
# 5       HSBC Holdings           4
# 6          PetroChina           3
# 7  Berkshire Hathaway           1
# 8         Wells Fargo           1
# 9           Petrobras           5

# %%
df_empresas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   empresa      10 non-null     object
#  1   codigo_pais  10 non-null     category
# dtypes: category(1), object(1)
# memory usage: 430.0+ bytes

# %%
df_empresas.describe()
# Out:
#             empresa  codigo_pais
# count            10           10
# unique           10            5
# top     Exxon Mobil            1
# freq              1            5

# %%
df_empresas['codigo_pais'].cat.categories
# Out:
# Index([1, 2, 3, 4, 5], dtype='int64')

# %%
df_empresas['codigo_pais'].cat.codes
# Out:
# 0    0
# 1    0
# 2    0
# 3    1
# 4    2
# 5    3
# 6    2
# 7    0
# 8    0
# 9    4
# dtype: int8

# %%
df_empresas['codigo_pais'].cat.ordered
# Out:
# False
