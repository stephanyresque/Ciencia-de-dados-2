# %% [markdown]
# <a href="https://colab.research.google.com/github/stephanyresque/Ciencia-de-dados-2/blob/main/04_11_24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

meses = ['Jan', 'Fev', 'Mar', 'Abr', 'Mai', 'Jun', 'Jul', 'Ago', 'Set', 'Out', 'Nov', 'Dez']
vendas = [85, 90, 78, 92, 88, 96, 94, 98, 100, 102, 105, 108]

# %%
fig, ax = plt.subplots()

ax.plot(meses, vendas)
ax.set_title('Vendas Mensais')
ax.set_xlabel('Mês')
ax.set_ylabel('Vendas')

plt.show()

# %%
produtos = ['Produto A', 'Produto B', 'Produto C', 'Produto D', 'Produto E']
quantidades = [23, 45, 17, 30, 37]

# %%
fig, ax = plt.subplots()

ax.bar(produtos,quantidades)
ax.set_title('Quantidade de vendas por produto')
ax.set_xlabel('Produtos')
ax.set_ylabel('Quantidades')
plt.show()

# %%
categorias = ['Eletrônicos', 'Roupas', 'Alimentos', 'Livros']
quantidades = [45, 30, 15, 10]
destaque = [0.1, 0, 0, 0]

# %%
fig, ax = plt.subplots()

ax.pie(quantidades, labels = categorias, explode = destaque, autopct="%.1f")

plt.show()

# %%
anos = [2018, 2019, 2020, 2021]
vendas_online = [5, 10, 15, 20]
vendas_loja = [10, 8, 6, 4]

# %%
fig, ax = plt.subplots()

ax.bar(anos, vendas_online, label = 'Vendas Online')
ax.bar(anos, vendas_loja, bottom = vendas_online,label = 'Vendas Loja')

ax.legend()
ax.set_title('Vendas Online VS Loja')
ax.set_xlabel('Ano')
ax.set_ylabel('Vendas (em milhões de reais)')

ax.set_xticks(anos)

plt.show()

# %%
meses = ['Jan', 'Fev', 'Mar', 'Abr', 'Mai', 'Jun', 'Jul', 'Ago', 'Set', 'Out', 'Nov', 'Dez']
precipitacao_media = [200, 180, 160, 100, 60, 30, 30, 35, 60, 100, 160, 200]
temperatura_media = [30, 29, 27, 25, 23, 22, 22, 23, 24, 25, 26, 28]

# %%
fig, ax1 = plt.subplots()

cor_temperatura = 'tab:red'
cor_precipitacao = 'tab:blue'

ax1.bar(meses, precipitacao_media, color = cor_precipitacao, label = 'Precipitação média (mm)')
ax1.set_ylabel('Precipitação (mm)', color = cor_precipitacao)
ax1.tick_params(axis = 'y', labelcolor = cor_precipitacao)

ax2 = ax1.twinx()
ax2.plot(meses, temperatura_media, color = cor_temperatura, linewidth = 2, label = 'Temperatura média (C°)')
ax2.set_ylabel('Temperatura (C°)', color = cor_temperatura)
ax2.tick_params(axis = 'y', labelcolor = cor_temperatura)
ax2.set_ylim(20, 30)

ax1.set_title("Temperatura de precipitação ao longo do ano")

fig.legend(bbox_to_anchor = (0.75,1), bbox_transform = ax1.transAxes)

plt.show()

# %%
fig, axs = plt.subplots(nrows=1, ncols=2)

plt.show()

# %%
print(axs)
print(axs[1])
# Out:
# [<Axes: > <Axes: >]
# Axes(0.547727,0.11;0.352273x0.77)

# %%
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(12, 4))

axs[0].plot(meses, vendas)
axs[1].bar(meses, vendas)

plt.show()

# %%
fig, axs = plt.subplots(nrows=2, ncols=2, figsize=(12, 10))

#gráfico 1
meses = ['Jan', 'Fev', 'Mar', 'Abr', 'Mai', 'Jun', 'Jul', 'Ago', 'Set', 'Out', 'Nov', 'Dez']
vendas = [85, 90, 78, 92, 88, 96, 94, 98, 100, 102, 105, 108]

axs[0,0].plot(meses, vendas)
axs[0,0].set_title('Vendas Mensais')
axs[0,0].set_xlabel('Mês')
axs[0,0].set_ylabel('Vendas')

#gráfico 2
produtos = ['Produto A', 'Produto B', 'Produto C', 'Produto D', 'Produto E']
quantidades = [23, 45, 17, 30, 37]

axs[0,1].bar(produtos,quantidades)
axs[0,1].set_title('Quantidade de vendas por produto')
axs[0,1].set_xlabel('Produtos')
axs[0,1].set_ylabel('Quantidades')

#gráfico 3
categorias = ['Eletrônicos', 'Roupas', 'Alimentos', 'Livros']
quantidades = [45, 30, 15, 10]
destaque = [0.1, 0, 0, 0]

axs[1,0].pie(quantidades, labels = categorias, explode = destaque, autopct="%.1f")
axs[1,0].set_title('Proporção de vendas por categoria')

#gráfico 4
anos = [2018, 2019, 2020, 2021]
vendas_online = [5, 10, 15, 20]
vendas_loja = [10, 8, 6, 4]

axs[1,1].bar(anos, vendas_online, label = 'Vendas Online')
axs[1,1].bar(anos, vendas_loja, bottom = vendas_online,label = 'Vendas Loja')

axs[1,1].legend()
axs[1,1].set_title('Vendas Online VS Loja')
axs[1,1].set_xlabel('Ano')
axs[1,1].set_ylabel('Vendas (em milhões de reais)')

axs[1,1].set_xticks(anos)

#ajustes finais
fig.suptitle('Evolução de vendas', fontsize = 16)

plt.show()
