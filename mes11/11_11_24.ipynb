# %% [markdown]
# <a href="https://colab.research.google.com/github/stephanyresque/Ciencia-de-dados-2/blob/main/11_11_24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
BASE = 'top_10_ibov_mai_ago_2023.csv'

df = pd.read_csv(BASE)

# %%
df['Date'] = pd.to_datetime(df['Date'], format = '%Y-%m-%d')

# %%
df = df.set_index('Date', drop = True)

# %%
df.head()
# Out:
#                 VALE3      ELET3      BBAS3      B3SA3  ABEV3      ITUB4  \
# Date
# 2023-01-02  87.478874  40.327332  31.615412  12.039818  14.19  23.893169
# 2023-01-03  87.322311  39.572250  31.026070  11.636853  14.17  23.395597
# 2023-01-04  87.478874  40.635326  31.425303  11.725308  14.25  23.463890
# 2023-01-05  88.946640  40.714806  32.860638  12.088961  14.29  24.195612
# 2023-01-06  90.355698  40.734676  33.316906  12.373984  14.32  24.615131
#
#                 BBDC4      WEGE3      PETR3      RENT3
# Date
# 2023-01-02  13.879215  37.771538  22.264847  50.636215
# 2023-01-03  13.190460  36.829731  21.950058  49.391312
# 2023-01-04  13.228148  37.077576  22.315893  49.974247
# 2023-01-05  13.802876  37.156883  23.039053  50.389210
# 2023-01-06  14.189168  37.702141  22.894421  51.347595

# %%
df.index
# Out:
# DatetimeIndex(['2023-01-02', '2023-01-03', '2023-01-04', '2023-01-05',
#                '2023-01-06', '2023-01-09', '2023-01-10', '2023-01-11',
#                '2023-01-12', '2023-01-13',
#                ...
#                '2023-06-16', '2023-06-19', '2023-06-20', '2023-06-21',
#                '2023-06-22', '2023-06-23', '2023-06-26', '2023-06-27',
#                '2023-06-28', '2023-06-29'],
#               dtype='datetime64[ns]', name='Date', length=123, freq=None)

# %%
fig, ax = plt.subplots()


ax.plot(df.index, df['BBDC4'])

plt.show()

# %%
fig, ax = plt.subplots()


ax.plot(df.index, df['BBDC4'], label = 'BBDC4')
ax.plot(df.index, df['ITUB4'], label = 'ITUB4')
ax.plot(df.index, df['BBAS3'], label = 'BBAS3')

ax.legend()
ax.set_title('Ações BBDC4, ITUB4 e BBAS3')
ax.set_ylabel('Valor em R$')

plt.show()

# %%
variacao_diaria = df.pct_change()
variacao_diaria.head()
# Out:
#                VALE3     ELET3     BBAS3     B3SA3     ABEV3     ITUB4  \
# Date
# 2023-01-02       NaN       NaN       NaN       NaN       NaN       NaN
# 2023-01-03 -0.001790 -0.018724 -0.018641 -0.033469 -0.001409 -0.020825
# 2023-01-04  0.001793  0.026864  0.012868  0.007601  0.005646  0.002919
# 2023-01-05  0.016779  0.001956  0.045675  0.031014  0.002807  0.031185
# 2023-01-06  0.015842  0.000488  0.013885  0.023577  0.002099  0.017339
#
#                BBDC4     WEGE3     PETR3     RENT3
# Date
# 2023-01-02       NaN       NaN       NaN       NaN
# 2023-01-03 -0.049625 -0.024934 -0.014138 -0.024585
# 2023-01-04  0.002857  0.006729  0.016667  0.011802
# 2023-01-05  0.043447  0.002139  0.032406  0.008304
# 2023-01-06  0.027986  0.014674 -0.006278  0.019020

# %%
fig, ax = plt.subplots()


ax.plot(variacao_diaria.index, variacao_diaria['BBDC4'], label = 'BBDC4')
ax.plot(variacao_diaria.index, variacao_diaria['ITUB4'], label = 'ITUB4')
ax.plot(variacao_diaria.index, variacao_diaria['BBAS3'], label = 'BBAS3')

ax.legend()
ax.set_title('Comparando a variação diária dos bancos top 10 IBOV')
ax.set_ylabel('Variação percentual')

plt.show()

# %%
plt.style.use('bmh')

# %%
fig, axs = plt.subplots(nrows=3, ncols=1, figsize = (10, 10))

bancos = ['BBDC4', 'ITUB4', 'BBAS3']

axs[0].plot(variacao_diaria.index, variacao_diaria['BBDC4'], label = 'BBDC4', color = 'C0')
axs[0].legend()
axs[1].plot(variacao_diaria.index, variacao_diaria['ITUB4'], label = 'ITUB4', color = 'C1' )
axs[1].legend()
axs[2].plot(variacao_diaria.index, variacao_diaria['BBAS3'], label = 'BBAS3', color = 'C2')
axs[2].legend()

plt.show()

# %%
fig, axs = plt.subplots(nrows=3, ncols=1, figsize = (10, 10))

bancos = ['BBDC4', 'ITUB4', 'BBAS3']

for i, banco in enumerate(bancos):
    axs[i].plot(variacao_diaria.index, variacao_diaria[banco], label = banco, color = 'C' + str(i))
    axs[i].legend()

plt.show()

# %%
fig, axs = plt.subplots(nrows=3, ncols=1, figsize = (10, 10))

bancos = ['BBDC4', 'ITUB4', 'BBAS3']

for i, banco in enumerate(bancos):
    axs[i].plot(variacao_diaria.index, variacao_diaria[banco], label = banco, color = 'C' + str(i))
    axs[i].legend()

fig.suptitle('Comparando a variação diária dos bancos top 10 IBOV', fontsize = 16)
fig.supylabel('Variação percentual', fontsize = 16)

plt.show()

# %%
fig, axs = plt.subplots(nrows=3, ncols=1, figsize = (10, 10), sharex = True)

bancos = ['BBDC4', 'ITUB4', 'BBAS3']

for i, banco in enumerate(bancos):
    axs[i].plot(variacao_diaria.index, variacao_diaria[banco], label = banco, color = 'C' + str(i))
    axs[i].legend()

fig.suptitle('Comparando a variação diária dos bancos top 10 IBOV', fontsize = 16)
fig.supylabel('Variação percentual', fontsize = 16)

plt.show()

# %%
fig, axs = plt.subplots(nrows=1, ncols=3, figsize = (10, 6))

axs[0].scatter('BBDC4','BBAS3', data = df)
axs[0].set_xlabel('BBDC4')
axs[0].set_ylabel('BBAS3')
axs[0].set_title('BBDC4 x BBAS3')

axs[1].scatter('BBDC4','ITUB4', data = df)
axs[1].set_xlabel('BBDC4')
axs[1].set_ylabel('ITUB4')
axs[1].set_title('BBDC4 x ITUB4')

axs[2].scatter('BBAS3','ITUB4', data = df)
axs[2].set_xlabel('BBAS3')
axs[2].set_ylabel('ITUB4')
axs[2].set_title('BBAS3 x ITUB4')

fig.suptitle('Analisando correlação dos bancos', fontsize = 16)

plt.show()

# %%
from itertools import combinations

print(list(combinations(bancos, 2)))
# Out:
# [('BBDC4', 'ITUB4'), ('BBDC4', 'BBAS3'), ('ITUB4', 'BBAS3')]

# %%
pares_bancos = list(combinations(bancos, 2))

# %%
fig, axs = plt.subplots(nrows=1, ncols=3, figsize = (12, 8))

for i, par in enumerate(pares_bancos):
  axs[i].scatter(par[0], par[1], data = df)
  axs[i].set_xlabel(par[0])
  axs[i].set_ylabel(par[1])
  axs[i].set_title(f'{par[0]} x {par[1]}')

fig.suptitle('Analisando correlação dos bancos', fontsize = 16)

plt.show()

# %%
df.corr()
# Out:
#           VALE3     ELET3     BBAS3     B3SA3     ABEV3     ITUB4     BBDC4  \
# VALE3  1.000000  0.254017 -0.801388 -0.472413 -0.733513 -0.616604 -0.630104
# ELET3  0.254017  1.000000  0.072803  0.641147  0.089652  0.421773  0.476954
# BBAS3 -0.801388  0.072803  1.000000  0.665027  0.666072  0.858388  0.753427
# B3SA3 -0.472413  0.641147  0.665027  1.000000  0.576847  0.806739  0.932840
# ABEV3 -0.733513  0.089652  0.666072  0.576847  1.000000  0.573089  0.670614
# ITUB4 -0.616604  0.421773  0.858388  0.806739  0.573089  1.000000  0.883379
# BBDC4 -0.630104  0.476954  0.753427  0.932840  0.670614  0.883379  1.000000
# WEGE3 -0.114228 -0.748048 -0.213368 -0.575233 -0.033395 -0.450325 -0.443264
# PETR3 -0.649903  0.350004  0.924637  0.805945  0.614360  0.917005  0.856235
# RENT3 -0.699430  0.331517  0.895541  0.864826  0.582085  0.892079  0.888734
#
#           WEGE3     PETR3     RENT3
# VALE3 -0.114228 -0.649903 -0.699430
# ELET3 -0.748048  0.350004  0.331517
# ...

# %%
df.corr().style.background_gradient(cmap = 'coolwarm_r')
# Out:
# <style type="text/css">
# #T_63530_row0_col0, #T_63530_row1_col1, #T_63530_row2_col2, #T_63530_row3_col3, #T_63530_row4_col4, #T_63530_row5_col5, #T_63530_row6_col6, #T_63530_row7_col7, #T_63530_row8_col8, #T_63530_row9_col9 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_63530_row0_col1 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_63530_row0_col2, #T_63530_row0_col4, #T_63530_row0_col5, #T_63530_row0_col6, #T_63530_row0_col8, #T_63530_row0_col9, #T_63530_row1_col7, #T_63530_row2_col0, #T_63530_row7_col1, #T_63530_row7_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_63530_row0_col3 {
#   background-color: #cb3e38;
#   color: #f1f1f1;
# }
# #T_63530_row0_col7 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_63530_row1_col0 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_63530_row1_col2 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_63530_row1_col3 {
#   background-color: #85a8fc;
# ...

# %%
df.corr().style.background_gradient(cmap = 'coolwarm_r', vmin = -1, vmax = 1)
# Out:
# <style type="text/css">
# #T_d5d23_row0_col0, #T_d5d23_row1_col1, #T_d5d23_row2_col2, #T_d5d23_row3_col3, #T_d5d23_row4_col4, #T_d5d23_row5_col5, #T_d5d23_row6_col6, #T_d5d23_row7_col7, #T_d5d23_row8_col8, #T_d5d23_row9_col9 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_d5d23_row0_col1, #T_d5d23_row1_col0 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_d5d23_row0_col2, #T_d5d23_row2_col0 {
#   background-color: #d65244;
#   color: #f1f1f1;
# }
# #T_d5d23_row0_col3, #T_d5d23_row3_col0 {
#   background-color: #f59f80;
#   color: #000000;
# }
# #T_d5d23_row0_col4, #T_d5d23_row4_col0 {
#   background-color: #e0654f;
#   color: #f1f1f1;
# }
# #T_d5d23_row0_col5, #T_d5d23_row5_col0 {
#   background-color: #ec8165;
#   color: #f1f1f1;
# }
# #T_d5d23_row0_col6, #T_d5d23_row6_col0 {
#   background-color: #eb7d62;
#   color: #f1f1f1;
# }
# #T_d5d23_row0_col7, #T_d5d23_row7_col0 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# ...

# %%
df.corr().style.format(precision = 2).background_gradient(cmap = 'coolwarm_r', vmin = -1, vmax = 1)
# Out:
# <style type="text/css">
# #T_51c3d_row0_col0, #T_51c3d_row1_col1, #T_51c3d_row2_col2, #T_51c3d_row3_col3, #T_51c3d_row4_col4, #T_51c3d_row5_col5, #T_51c3d_row6_col6, #T_51c3d_row7_col7, #T_51c3d_row8_col8, #T_51c3d_row9_col9 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_51c3d_row0_col1, #T_51c3d_row1_col0 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_51c3d_row0_col2, #T_51c3d_row2_col0 {
#   background-color: #d65244;
#   color: #f1f1f1;
# }
# #T_51c3d_row0_col3, #T_51c3d_row3_col0 {
#   background-color: #f59f80;
#   color: #000000;
# }
# #T_51c3d_row0_col4, #T_51c3d_row4_col0 {
#   background-color: #e0654f;
#   color: #f1f1f1;
# }
# #T_51c3d_row0_col5, #T_51c3d_row5_col0 {
#   background-color: #ec8165;
#   color: #f1f1f1;
# }
# #T_51c3d_row0_col6, #T_51c3d_row6_col0 {
#   background-color: #eb7d62;
#   color: #f1f1f1;
# }
# #T_51c3d_row0_col7, #T_51c3d_row7_col0 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# ...

# %%
bancos
# Out:
# ['BBDC4', 'ITUB4', 'BBAS3']

# %%
df[bancos].corr().style.format(precision = 2).background_gradient(cmap = 'coolwarm_r', vmin = 0, vmax = 1)
# Out:
# <style type="text/css">
# #T_01e23_row0_col0, #T_01e23_row1_col1, #T_01e23_row2_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_01e23_row0_col1, #T_01e23_row1_col0 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_01e23_row0_col2, #T_01e23_row2_col0 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_01e23_row1_col2, #T_01e23_row2_col1 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_01e23" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_01e23_level0_col0" class="col_heading level0 col0" >BBDC4</th>
#       <th id="T_01e23_level0_col1" class="col_heading level0 col1" >ITUB4</th>
#       <th id="T_01e23_level0_col2" class="col_heading level0 col2" >BBAS3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_01e23_level0_row0" class="row_heading level0 row0" >BBDC4</th>
#       <td id="T_01e23_row0_col0" class="data row0 col0" >1.00</td>
# ...

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(df, figsize = (14,14));

# %%
df['VALE3'].value_counts(bins = 10).sort_index()
# Out:
# (63.777, 67.018]    16
# (67.018, 70.227]    26
# (70.227, 73.435]     5
# (73.435, 76.644]     2
# (76.644, 79.852]    12
# (79.852, 83.06]     12
# (83.06, 86.269]     17
# (86.269, 89.477]    14
# (89.477, 92.686]    14
# (92.686, 95.894]     5
# Name: count, dtype: int64

# %%
scatter_matrix(df, figsize = (12,12), hist_kwds={'bins':10, 'edgecolor':'black'});
