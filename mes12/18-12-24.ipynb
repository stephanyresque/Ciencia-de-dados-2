# %%
import pandas as pd
import numpy as np

DATA = 'C:\\Users\\steph\\OneDrive\\Documentos\\MeusProjetos\\Ciencia-de-dados\\dados_hash\\carrots.csv'

df = pd.read_csv(DATA)

df.head()
# Out:
#    carrots
# 0     45.0
# 1     44.5
# 2     44.0
# 3     45.0
# 4     46.5

# %%
df.describe()
# Out:
#          carrots
# count  20.000000
# mean   45.300000
# std     0.700376
# min    44.000000
# 25%    44.875000
# 50%    45.000000
# 75%    45.850000
# max    46.500000

# %%
import seaborn as sns

sns.boxplot(data = df, x = 'carrots')
# Out:
# <Axes: xlabel='carrots'>

# %%
sns.boxplot(data = df, x = 'carrots', showmeans = True)
# Out:
# <Axes: xlabel='carrots'>

# %%
sns.histplot(data = df, x = 'carrots', kde = True, bins = 'sturges')
# Out:
# <Axes: xlabel='carrots', ylabel='Count'>

# %%
import matplotlib.pyplot as plt

fig, (ax1, ax2) = plt.subplots(nrows = 2, ncols = 1)

sns.boxplot(data = df, x = 'carrots', showmeans = True, ax = ax1)
sns.histplot(data = df, x = 'carrots', kde = True, bins = 'sturges', ax = ax2)

plt.show()

# %%
import matplotlib.pyplot as plt

fig, (ax1, ax2) = plt.subplots(
    nrows = 2, 
    ncols = 1, 
    sharex=True,
    gridspec_kw={
        'height_ratios': (0.15, 0.85),
        'hspace': 0.02
    }
)

sns.boxplot(data = df, x = 'carrots', showmeans = True, ax = ax1)
sns.histplot(data = df, x = 'carrots', kde = True, bins = 'sturges', ax = ax2)

for ax in (ax1, ax2):
    ax.grid(True, linestyle = '--', color = 'gray', alpha = 0.5)
    ax.set_axisbelow(True)

plt.show()

# %%
import matplotlib.pyplot as plt

fig, (ax1, ax2) = plt.subplots(
    nrows = 2, 
    ncols = 1, 
    sharex=True,
    gridspec_kw={
        'height_ratios': (0.15, 0.85),
        'hspace': 0.02
    }
)

sns.boxplot(
    data = df, 
    x = 'carrots', 
    showmeans = True, 
    ax = ax1, 
    meanline = True,
    meanprops = {'color': 'C1', 'linewidth': 1.5},
    medianprops = {'color': 'C2', 'linewidth': 1.5, 'linestyle':'--'},
)

sns.histplot(data = df, x = 'carrots', kde = True, bins = 'sturges', ax = ax2)

for ax in (ax1, ax2):
    ax.grid(True, linestyle = '--', color = 'gray', alpha = 0.5)
    ax.set_axisbelow(True)

ax2.axvline(df['carrots'].mean(), color = 'C1', linestyle = '--', label = 'Média')
ax2.axvline(df['carrots'].median(), color = 'C2', linestyle = '--', label = 'Mediana')
ax2.axvline(df['carrots'].mode()[0], color = 'C3', linestyle = '--', label = 'Moda')
ax2.legend()

plt.show()
