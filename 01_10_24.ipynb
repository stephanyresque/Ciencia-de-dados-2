# %% [markdown]
# <a href="https://colab.research.google.com/github/stephanyresque/Ciencia-de-dados-2/blob/main/01_10_24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('cereal.csv')

# %% [markdown]
# # Principais checagens - pt2

# %%
df.describe()
# Out:
#          calories    protein        fat      sodium      fiber      carbo  \
# count   77.000000  77.000000  77.000000   77.000000  77.000000  77.000000
# mean   106.883117   2.545455   1.012987  159.675325   2.151948  14.597403
# std     19.484119   1.094790   1.006473   83.832295   2.383364   4.278956
# min     50.000000   1.000000   0.000000    0.000000   0.000000  -1.000000
# 25%    100.000000   2.000000   0.000000  130.000000   1.000000  12.000000
# 50%    110.000000   3.000000   1.000000  180.000000   2.000000  14.000000
# 75%    110.000000   3.000000   2.000000  210.000000   3.000000  17.000000
# max    160.000000   6.000000   5.000000  320.000000  14.000000  23.000000
#
#           sugars      potass    vitamins      shelf     weight       cups  \
# count  77.000000   77.000000   77.000000  77.000000  77.000000  77.000000
# mean    6.922078   96.077922   28.246753   2.207792   1.029610   0.821039
# std     4.444885   71.286813   22.342523   0.832524   0.150477   0.232716
# ...

# %%
with pd.option_context("float_format", "{:.2f}".format):
  display(df.describe())
# Out:
#        calories  protein   fat  sodium  fiber  carbo  sugars  potass  \
# count     77.00    77.00 77.00   77.00  77.00  77.00   77.00   77.00
# mean     106.88     2.55  1.01  159.68   2.15  14.60    6.92   96.08
# std       19.48     1.09  1.01   83.83   2.38   4.28    4.44   71.29
# min       50.00     1.00  0.00    0.00   0.00  -1.00   -1.00   -1.00
# 25%      100.00     2.00  0.00  130.00   1.00  12.00    3.00   40.00
# 50%      110.00     3.00  1.00  180.00   2.00  14.00    7.00   90.00
# 75%      110.00     3.00  2.00  210.00   3.00  17.00   11.00  120.00
# max      160.00     6.00  5.00  320.00  14.00  23.00   15.00  330.00
#
#        vitamins  shelf  weight  cups  rating
# count     77.00  77.00   77.00 77.00   77.00
# mean      28.25   2.21    1.03  0.82   42.67
# std       22.34   0.83    0.15  0.23   14.05
# min        0.00   1.00    0.50  0.25   18.04
# 25%       25.00   1.00    1.00  0.67   33.17
# 50%       25.00   2.00    1.00  0.75   40.40
# ...

# %%
df.describe(exclude = "number")
# Out:
#              name mfr type
# count          77  77   77
# unique         77   7    2
# top     100% Bran   K    C
# freq            1  23   74

# %%
df.nunique()
# Out:
# name        77
# mfr          7
# type         2
# calories    11
# protein      6
# fat          5
# sodium      27
# fiber       13
# carbo       22
# sugars      17
# potass      36
# vitamins     3
# shelf        3
# weight       7
# cups        12
# rating      77
# dtype: int64

# %%
df.select_dtypes('object')
# Out:
#                          name mfr type
# 0                   100% Bran   N    C
# 1           100% Natural Bran   Q    C
# 2                    All-Bran   K    C
# 3   All-Bran with Extra Fiber   K    C
# 4              Almond Delight   R    C
# ..                        ...  ..  ...
# 72                    Triples   G    C
# 73                       Trix   G    C
# 74                 Wheat Chex   R    C
# 75                   Wheaties   G    C
# 76        Wheaties Honey Gold   G    C
#
# [77 rows x 3 columns]

# %%
df.select_dtypes('object').nunique()
# Out:
# name    77
# mfr      7
# type     2
# dtype: int64

# %%
df["mfr"].unique()
# Out:
# array(['N', 'Q', 'K', 'R', 'G', 'P', 'A'], dtype=object)

# %%
df['type'].unique()
# Out:
# array(['C', 'H'], dtype=object)

# %%
df['type'].nunique()
# Out:
# 2

# %%
df.select_dtypes('number')
# Out:
#     calories  protein  fat  sodium  fiber  carbo  sugars  potass  vitamins  \
# 0         70        4    1     130   10.0    5.0       6     280        25
# 1        120        3    5      15    2.0    8.0       8     135         0
# 2         70        4    1     260    9.0    7.0       5     320        25
# 3         50        4    0     140   14.0    8.0       0     330        25
# 4        110        2    2     200    1.0   14.0       8      -1        25
# ..       ...      ...  ...     ...    ...    ...     ...     ...       ...
# 72       110        2    1     250    0.0   21.0       3      60        25
# 73       110        1    1     140    0.0   13.0      12      25        25
# 74       100        3    1     230    3.0   17.0       3     115        25
# 75       100        3    1     200    3.0   17.0       3     110        25
# 76       110        2    1     200    1.0   16.0       8      60        25
#
#     shelf  weight  cups     rating
# ...

# %%
df.select_dtypes('number') == 1
# Out:
#     calories  protein    fat  sodium  fiber  carbo  sugars  potass  vitamins  \
# 0      False    False   True   False  False  False   False   False     False
# 1      False    False  False   False  False  False   False   False     False
# 2      False    False   True   False  False  False   False   False     False
# 3      False    False  False   False  False  False   False   False     False
# 4      False    False  False   False   True  False   False   False     False
# ..       ...      ...    ...     ...    ...    ...     ...     ...       ...
# 72     False    False   True   False  False  False   False   False     False
# 73     False     True   True   False  False  False   False   False     False
# 74     False    False   True   False  False  False   False   False     False
# 75     False    False   True   False  False  False   False   False     False
# 76     False    False   True   False   True  False   False   False     False
#
#     shelf  weight   cups  rating
# ...

# %%
(df.select_dtypes('number') == -1).sum()
# Out:
# calories    0
# protein     0
# fat         0
# sodium      0
# fiber       0
# carbo       1
# sugars      1
# potass      2
# vitamins    0
# shelf       0
# weight      0
# cups        0
# rating      0
# dtype: int64

# %%
df.duplicated() #checar se há algum dado duplicado
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 72    False
# 73    False
# 74    False
# 75    False
# 76    False
# Length: 77, dtype: bool

# %%
(df.duplicated()).sum()
# Out:
# 0

# %%
df['mfr'].value_counts()
# Out:
# mfr
# K    23
# G    22
# P     9
# Q     8
# R     8
# N     6
# A     1
# Name: count, dtype: int64

# %%
df['type'].value_counts()
# Out:
# type
# C    74
# H     3
# Name: count, dtype: int64

# %%
df['shelf'].value_counts()
# Out:
# shelf
# 3    36
# 2    21
# 1    20
# Name: count, dtype: int64

# %% [markdown]
# # Selecionando partes

# %%
df.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0    5.0       6     280        25      3     1.0  0.33  68.402973
# 1    8.0       8     135         0      3     1.0  1.00  33.983679
# 2    7.0       5     320        25      3     1.0  0.33  59.425505
# 3    8.0       0     330        25      3     1.0  0.50  93.704912
# 4   14.0       8      -1        25      3     1.0  0.75  34.384843

# %%
df[['name', 'rating']]
# Out:
#                          name     rating
# 0                   100% Bran  68.402973
# 1           100% Natural Bran  33.983679
# 2                    All-Bran  59.425505
# 3   All-Bran with Extra Fiber  93.704912
# 4              Almond Delight  34.384843
# ..                        ...        ...
# 72                    Triples  39.106174
# 73                       Trix  27.753301
# 74                 Wheat Chex  49.787445
# 75                   Wheaties  51.592193
# 76        Wheaties Honey Gold  36.187559
#
# [77 rows x 2 columns]

# %%
df[0:5] #linha 0 até a 4
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0    5.0       6     280        25      3     1.0  0.33  68.402973
# 1    8.0       8     135         0      3     1.0  1.00  33.983679
# 2    7.0       5     320        25      3     1.0  0.33  59.425505
# 3    8.0       0     330        25      3     1.0  0.50  93.704912
# 4   14.0       8      -1        25      3     1.0  0.75  34.384843

# %%
df[1:8]
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
# 5    Apple Cinnamon Cheerios   G    C       110        2    2     180    1.5
# 6                Apple Jacks   K    C       110        2    0     125    1.0
# 7                    Basic 4   G    C       130        3    2     210    2.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 1    8.0       8     135         0      3    1.00  1.00  33.983679
# 2    7.0       5     320        25      3    1.00  0.33  59.425505
# 3    8.0       0     330        25      3    1.00  0.50  93.704912
# 4   14.0       8      -1        25      3    1.00  0.75  34.384843
# ...

# %%
#iloc = seleciona linhas e colunas por índice
#loc = seleciona linhas e colunas por nome

# %%
df.iloc[0:5]
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0    5.0       6     280        25      3     1.0  0.33  68.402973
# 1    8.0       8     135         0      3     1.0  1.00  33.983679
# 2    7.0       5     320        25      3     1.0  0.33  59.425505
# 3    8.0       0     330        25      3     1.0  0.50  93.704912
# 4   14.0       8      -1        25      3     1.0  0.75  34.384843

# %%
df.iloc[0:5, 0:3] #linha 0 até a 4, coluna 0 a 2
# Out:
#                         name mfr type
# 0                  100% Bran   N    C
# 1          100% Natural Bran   Q    C
# 2                   All-Bran   K    C
# 3  All-Bran with Extra Fiber   K    C
# 4             Almond Delight   R    C

# %%
df.iloc[0:5, [0, 2]] #linha 0 até a 4, coluna 0 e 2
# Out:
#                         name type
# 0                  100% Bran    C
# 1          100% Natural Bran    C
# 2                   All-Bran    C
# 3  All-Bran with Extra Fiber    C
# 4             Almond Delight    C

# %%
df.loc[0:5] #do nome 0 ao nome 5 ->inclui o 5
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
# 5    Apple Cinnamon Cheerios   G    C       110        2    2     180    1.5
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0    5.0       6     280        25      3     1.0  0.33  68.402973
# 1    8.0       8     135         0      3     1.0  1.00  33.983679
# 2    7.0       5     320        25      3     1.0  0.33  59.425505
# 3    8.0       0     330        25      3     1.0  0.50  93.704912
# 4   14.0       8      -1        25      3     1.0  0.75  34.384843
# ...

# %%
df.loc[0:5, ['name', 'rating']]
# Out:
#                         name     rating
# 0                  100% Bran  68.402973
# 1          100% Natural Bran  33.983679
# 2                   All-Bran  59.425505
# 3  All-Bran with Extra Fiber  93.704912
# 4             Almond Delight  34.384843
# 5    Apple Cinnamon Cheerios  29.509541

# %%
#olhar com condição

df[df['rating'] > 70]
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 64     Shredded Wheat 'n'Bran   N    C        90        3    0       0    4.0
# 65  Shredded Wheat spoon size   N    C        90        3    0       0    3.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 3     8.0       0     330        25      3     1.0  0.50  93.704912
# 64   19.0       0     140         0      1     1.0  0.67  74.472949
# 65   20.0       0     120         0      1     1.0  0.67  72.801787

# %%
df[df['rating'] > 70][['name', 'rating']]
# Out:
#                          name     rating
# 3   All-Bran with Extra Fiber  93.704912
# 64     Shredded Wheat 'n'Bran  74.472949
# 65  Shredded Wheat spoon size  72.801787

# %%
df[df['name'] == 'Almond Delight']
# Out:
#              name mfr type  calories  protein  fat  sodium  fiber  carbo  \
# 4  Almond Delight   R    C       110        2    2     200    1.0   14.0
#
#    sugars  potass  vitamins  shelf  weight  cups     rating
# 4       8      -1        25      3     1.0  0.75  34.384843

# %%
df[df['mfr'] == 'N']
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 20     Cream of Wheat (Quick)   N    H       100        3    0      80    1.0
# 63             Shredded Wheat   N    C        80        2    0       0    3.0
# 64     Shredded Wheat 'n'Bran   N    C        90        3    0       0    4.0
# 65  Shredded Wheat spoon size   N    C        90        3    0       0    3.0
# 68    Strawberry Fruit Wheats   N    C        90        2    0      15    3.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0     5.0       6     280        25      3    1.00  0.33  68.402973
# 20   21.0       0      -1         0      2    1.00  1.00  64.533816
# 63   16.0       0      95         0      1    0.83  1.00  68.235885
# 64   19.0       0     140         0      1    1.00  0.67  74.472949
# 65   20.0       0     120         0      1    1.00  0.67  72.801787
# ...

# %%
df[(df['mfr'] == 'N') & (df['type'] == 'H')]
# Out:
#                       name mfr type  calories  protein  fat  sodium  fiber  \
# 20  Cream of Wheat (Quick)   N    H       100        3    0      80    1.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 20   21.0       0      -1         0      2     1.0   1.0  64.533816

# %%
df[(df['mfr'] == 'N') | (df['type'] == 'H')]
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 20     Cream of Wheat (Quick)   N    H       100        3    0      80    1.0
# 43                      Maypo   A    H       100        4    1       0    0.0
# 57             Quaker Oatmeal   Q    H       100        5    2       0    2.7
# 63             Shredded Wheat   N    C        80        2    0       0    3.0
# 64     Shredded Wheat 'n'Bran   N    C        90        3    0       0    4.0
# 65  Shredded Wheat spoon size   N    C        90        3    0       0    3.0
# 68    Strawberry Fruit Wheats   N    C        90        2    0      15    3.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0     5.0       6     280        25      3    1.00  0.33  68.402973
# 20   21.0       0      -1         0      2    1.00  1.00  64.533816
# ...

# %%
df[(df['mfr'] == 'N') & (df['type'] == 'C')]
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 63             Shredded Wheat   N    C        80        2    0       0    3.0
# 64     Shredded Wheat 'n'Bran   N    C        90        3    0       0    4.0
# 65  Shredded Wheat spoon size   N    C        90        3    0       0    3.0
# 68    Strawberry Fruit Wheats   N    C        90        2    0      15    3.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0     5.0       6     280        25      3    1.00  0.33  68.402973
# 63   16.0       0      95         0      1    0.83  1.00  68.235885
# 64   19.0       0     140         0      1    1.00  0.67  74.472949
# 65   20.0       0     120         0      1    1.00  0.67  72.801787
# 68   15.0       5      90        25      2    1.00  1.00  59.363993

# %%
df[(df['mfr'] == 'N') & ~(df['type'] == 'H')] #não seja 'H'
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 63             Shredded Wheat   N    C        80        2    0       0    3.0
# 64     Shredded Wheat 'n'Bran   N    C        90        3    0       0    4.0
# 65  Shredded Wheat spoon size   N    C        90        3    0       0    3.0
# 68    Strawberry Fruit Wheats   N    C        90        2    0      15    3.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0     5.0       6     280        25      3    1.00  0.33  68.402973
# 63   16.0       0      95         0      1    0.83  1.00  68.235885
# 64   19.0       0     140         0      1    1.00  0.67  74.472949
# 65   20.0       0     120         0      1    1.00  0.67  72.801787
# 68   15.0       5      90        25      2    1.00  1.00  59.363993

# %%
df[df['mfr'].isin(['R','N', 'A'])] #isin é "está em"
# Out:
#                                  name mfr type  calories  protein  fat  \
# 0                           100% Bran   N    C        70        4    1
# 4                      Almond Delight   R    C       110        2    2
# 8                           Bran Chex   R    C        90        2    1
# 15                          Corn Chex   R    C       110        2    0
# 20             Cream of Wheat (Quick)   N    H       100        3    0
# 23                        Double Chex   R    C       100        2    0
# 43                              Maypo   A    H       100        4    1
# 44   Muesli Raisins; Dates; & Almonds   R    C       150        4    3
# 45  Muesli Raisins; Peaches; & Pecans   R    C       150        4    3
# 61                          Rice Chex   R    C       110        1    0
# 63                     Shredded Wheat   N    C        80        2    0
# 64             Shredded Wheat 'n'Bran   N    C        90        3    0
# ...

# %%
with pd.option_context("float_format", "{:.2f}".format):
  display(df.describe())
# Out:
#        calories  protein   fat  sodium  fiber  carbo  sugars  potass  \
# count     77.00    77.00 77.00   77.00  77.00  77.00   77.00   77.00
# mean     106.88     2.55  1.01  159.68   2.15  14.60    6.92   96.08
# std       19.48     1.09  1.01   83.83   2.38   4.28    4.44   71.29
# min       50.00     1.00  0.00    0.00   0.00  -1.00   -1.00   -1.00
# 25%      100.00     2.00  0.00  130.00   1.00  12.00    3.00   40.00
# 50%      110.00     3.00  1.00  180.00   2.00  14.00    7.00   90.00
# 75%      110.00     3.00  2.00  210.00   3.00  17.00   11.00  120.00
# max      160.00     6.00  5.00  320.00  14.00  23.00   15.00  330.00
#
#        vitamins  shelf  weight  cups  rating
# count     77.00  77.00   77.00 77.00   77.00
# mean      28.25   2.21    1.03  0.82   42.67
# std       22.34   0.83    0.15  0.23   14.05
# min        0.00   1.00    0.50  0.25   18.04
# 25%       25.00   1.00    1.00  0.67   33.17
# 50%       25.00   2.00    1.00  0.75   40.40
# ...

# %%
(df.select_dtypes('number') == -1).sum()
# Out:
# calories    0
# protein     0
# fat         0
# sodium      0
# fiber       0
# carbo       1
# sugars      1
# potass      2
# vitamins    0
# shelf       0
# weight      0
# cups        0
# rating      0
# dtype: int64

# %%
df[(df['carbo'] == -1) | (df['sugars'] == -1) | (df['potass'] == -1)]
# Out:
#                       name mfr type  calories  protein  fat  sodium  fiber  \
# 4           Almond Delight   R    C       110        2    2     200    1.0
# 20  Cream of Wheat (Quick)   N    H       100        3    0      80    1.0
# 57          Quaker Oatmeal   Q    H       100        5    2       0    2.7
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 4    14.0       8      -1        25      3     1.0  0.75  34.384843
# 20   21.0       0      -1         0      2     1.0  1.00  64.533816
# 57   -1.0      -1     110         0      1     1.0  0.67  50.828392

# %%
df['rating'].min()
# Out:
# 18.042851

# %%
df['rating'].idxmax() #retorna o índice
# Out:
# 3

# %%
df.loc[df['rating'].idxmax()]
# Out:
# name        All-Bran with Extra Fiber
# mfr                                 K
# type                                C
# calories                           50
# protein                             4
# fat                                 0
# sodium                            140
# fiber                            14.0
# carbo                             8.0
# sugars                              0
# potass                            330
# vitamins                           25
# shelf                               3
# weight                            1.0
# cups                              0.5
# rating                      93.704912
# Name: 3, dtype: object

# %%
df.loc[df['rating'].idxmin()]
# Out:
# name        Cap'n'Crunch
# mfr                    Q
# type                   C
# calories             120
# protein                1
# fat                    2
# sodium               220
# fiber                0.0
# carbo               12.0
# sugars                12
# potass                35
# vitamins              25
# shelf                  2
# weight               1.0
# cups                0.75
# rating         18.042851
# Name: 10, dtype: object

# %% [markdown]
# ## usando query

# %%
df.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0    5.0       6     280        25      3     1.0  0.33  68.402973
# 1    8.0       8     135         0      3     1.0  1.00  33.983679
# 2    7.0       5     320        25      3     1.0  0.33  59.425505
# 3    8.0       0     330        25      3     1.0  0.50  93.704912
# 4   14.0       8      -1        25      3     1.0  0.75  34.384843

# %%
# df[df['rating'] > 70]

df.query("rating > 70")
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 64     Shredded Wheat 'n'Bran   N    C        90        3    0       0    4.0
# 65  Shredded Wheat spoon size   N    C        90        3    0       0    3.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 3     8.0       0     330        25      3     1.0  0.50  93.704912
# 64   19.0       0     140         0      1     1.0  0.67  74.472949
# 65   20.0       0     120         0      1     1.0  0.67  72.801787

# %%
# df[df['rating'] > 70][['name', 'rating']]

df.query("rating > 70")[['name', 'rating']]
# Out:
#                          name     rating
# 3   All-Bran with Extra Fiber  93.704912
# 64     Shredded Wheat 'n'Bran  74.472949
# 65  Shredded Wheat spoon size  72.801787

# %%
# df[df['name'] == 'Almond Delight']

df.query("name == 'Almond Delight'")
# Out:
#              name mfr type  calories  protein  fat  sodium  fiber  carbo  \
# 4  Almond Delight   R    C       110        2    2     200    1.0   14.0
#
#    sugars  potass  vitamins  shelf  weight  cups     rating
# 4       8      -1        25      3     1.0  0.75  34.384843

# %%
# df[df['mfr'] == "N"]

df.query("mfr == 'N'")
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 20     Cream of Wheat (Quick)   N    H       100        3    0      80    1.0
# 63             Shredded Wheat   N    C        80        2    0       0    3.0
# 64     Shredded Wheat 'n'Bran   N    C        90        3    0       0    4.0
# 65  Shredded Wheat spoon size   N    C        90        3    0       0    3.0
# 68    Strawberry Fruit Wheats   N    C        90        2    0      15    3.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0     5.0       6     280        25      3    1.00  0.33  68.402973
# 20   21.0       0      -1         0      2    1.00  1.00  64.533816
# 63   16.0       0      95         0      1    0.83  1.00  68.235885
# 64   19.0       0     140         0      1    1.00  0.67  74.472949
# 65   20.0       0     120         0      1    1.00  0.67  72.801787
# ...

# %%
# df[(df['mfr'] == "N") & (df['type'] == 'H')]

df.query("mfr == 'N' and type == 'H'")
# Out:
#                       name mfr type  calories  protein  fat  sodium  fiber  \
# 20  Cream of Wheat (Quick)   N    H       100        3    0      80    1.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 20   21.0       0      -1         0      2     1.0   1.0  64.533816

# %%
# df[(df['mfr'] == "N") & ~(df['type'] == 'H')]

df.query("mfr == 'N' and not type == 'H'")
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 63             Shredded Wheat   N    C        80        2    0       0    3.0
# 64     Shredded Wheat 'n'Bran   N    C        90        3    0       0    4.0
# 65  Shredded Wheat spoon size   N    C        90        3    0       0    3.0
# 68    Strawberry Fruit Wheats   N    C        90        2    0      15    3.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0     5.0       6     280        25      3    1.00  0.33  68.402973
# 63   16.0       0      95         0      1    0.83  1.00  68.235885
# 64   19.0       0     140         0      1    1.00  0.67  74.472949
# 65   20.0       0     120         0      1    1.00  0.67  72.801787
# 68   15.0       5      90        25      2    1.00  1.00  59.363993

# %%
# df[(df['mfr'] == "N") | (df['type'] == 'H')]

df.query("mfr == 'N' or type == 'H'")
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 20     Cream of Wheat (Quick)   N    H       100        3    0      80    1.0
# 43                      Maypo   A    H       100        4    1       0    0.0
# 57             Quaker Oatmeal   Q    H       100        5    2       0    2.7
# 63             Shredded Wheat   N    C        80        2    0       0    3.0
# 64     Shredded Wheat 'n'Bran   N    C        90        3    0       0    4.0
# 65  Shredded Wheat spoon size   N    C        90        3    0       0    3.0
# 68    Strawberry Fruit Wheats   N    C        90        2    0      15    3.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0     5.0       6     280        25      3    1.00  0.33  68.402973
# 20   21.0       0      -1         0      2    1.00  1.00  64.533816
# ...

# %%
# df[df['mfr'].isin(['R', 'N', 'A'])]

df.query("mfr in ['R', 'N', 'A']")
# Out:
#                                  name mfr type  calories  protein  fat  \
# 0                           100% Bran   N    C        70        4    1
# 4                      Almond Delight   R    C       110        2    2
# 8                           Bran Chex   R    C        90        2    1
# 15                          Corn Chex   R    C       110        2    0
# 20             Cream of Wheat (Quick)   N    H       100        3    0
# 23                        Double Chex   R    C       100        2    0
# 43                              Maypo   A    H       100        4    1
# 44   Muesli Raisins; Dates; & Almonds   R    C       150        4    3
# 45  Muesli Raisins; Peaches; & Pecans   R    C       150        4    3
# 61                          Rice Chex   R    C       110        1    0
# 63                     Shredded Wheat   N    C        80        2    0
# 64             Shredded Wheat 'n'Bran   N    C        90        3    0
# ...

# %%
with pd.option_context("float_format", "{:.2f}".format):
  display(df.describe())
# Out:
#        calories  protein   fat  sodium  fiber  carbo  sugars  potass  \
# count     77.00    77.00 77.00   77.00  77.00  77.00   77.00   77.00
# mean     106.88     2.55  1.01  159.68   2.15  14.60    6.92   96.08
# std       19.48     1.09  1.01   83.83   2.38   4.28    4.44   71.29
# min       50.00     1.00  0.00    0.00   0.00  -1.00   -1.00   -1.00
# 25%      100.00     2.00  0.00  130.00   1.00  12.00    3.00   40.00
# 50%      110.00     3.00  1.00  180.00   2.00  14.00    7.00   90.00
# 75%      110.00     3.00  2.00  210.00   3.00  17.00   11.00  120.00
# max      160.00     6.00  5.00  320.00  14.00  23.00   15.00  330.00
#
#        vitamins  shelf  weight  cups  rating
# count     77.00  77.00   77.00 77.00   77.00
# mean      28.25   2.21    1.03  0.82   42.67
# std       22.34   0.83    0.15  0.23   14.05
# min        0.00   1.00    0.50  0.25   18.04
# 25%       25.00   1.00    1.00  0.67   33.17
# 50%       25.00   2.00    1.00  0.75   40.40
# ...

# %%
# df[(df['carbo'] == -1) | (df['sugars'] == -1) | (df['potass'] == -1)]

df.query("carbo == -1 or sugars == -1 or potass == -1")
# Out:
#                       name mfr type  calories  protein  fat  sodium  fiber  \
# 4           Almond Delight   R    C       110        2    2     200    1.0
# 20  Cream of Wheat (Quick)   N    H       100        3    0      80    1.0
# 57          Quaker Oatmeal   Q    H       100        5    2       0    2.7
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 4    14.0       8      -1        25      3     1.0  0.75  34.384843
# 20   21.0       0      -1         0      2     1.0  1.00  64.533816
# 57   -1.0      -1     110         0      1     1.0  0.67  50.828392

# %% [markdown]
# # Agrupamentos

# %%
df.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0    5.0       6     280        25      3     1.0  0.33  68.402973
# 1    8.0       8     135         0      3     1.0  1.00  33.983679
# 2    7.0       5     320        25      3     1.0  0.33  59.425505
# 3    8.0       0     330        25      3     1.0  0.50  93.704912
# 4   14.0       8      -1        25      3     1.0  0.75  34.384843

# %%
df.groupby("mfr") #afrupar com relação a "mfr"

# %%
df.groupby("mfr")['rating'].mean()
# Out:
# mfr
# A    54.850917
# G    34.485852
# K    44.038462
# N    67.968567
# P    41.705744
# Q    42.915990
# R    41.542997
# Name: rating, dtype: float64

# %%
df.query("mfr == 'A'")
# Out:
#      name mfr type  calories  protein  fat  sodium  fiber  carbo  sugars  \
# 43  Maypo   A    H       100        4    1       0    0.0   16.0       3
#
#     potass  vitamins  shelf  weight  cups     rating
# 43      95        25      2     1.0   1.0  54.850917

# %%
df.groupby("mfr")[['calories', 'rating']].mean()
# Out:
#        calories     rating
# mfr
# A    100.000000  54.850917
# G    111.363636  34.485852
# K    108.695652  44.038462
# N     86.666667  67.968567
# P    108.888889  41.705744
# Q     95.000000  42.915990
# R    115.000000  41.542997

# %%
df.groupby("mfr")[['calories', 'rating']].mean().sort_values('rating')
# Out:
#        calories     rating
# mfr
# G    111.363636  34.485852
# R    115.000000  41.542997
# P    108.888889  41.705744
# Q     95.000000  42.915990
# K    108.695652  44.038462
# A    100.000000  54.850917
# N     86.666667  67.968567

# %%
df.groupby("mfr")[['calories', 'rating']].mean().sort_values('rating', ascending = False)
# Out:
#        calories     rating
# mfr
# N     86.666667  67.968567
# A    100.000000  54.850917
# K    108.695652  44.038462
# Q     95.000000  42.915990
# P    108.888889  41.705744
# R    115.000000  41.542997
# G    111.363636  34.485852

# %%
df.groupby("mfr")["calories"].describe()
# Out:
#      count        mean        std    min    25%    50%    75%    max
# mfr
# A      1.0  100.000000        NaN  100.0  100.0  100.0  100.0  100.0
# G     22.0  111.363636  10.371873  100.0  110.0  110.0  110.0  140.0
# K     23.0  108.695652  22.218818   50.0  100.0  110.0  115.0  160.0
# N      6.0   86.666667  10.327956   70.0   82.5   90.0   90.0  100.0
# P      9.0  108.888889  10.540926   90.0  100.0  110.0  120.0  120.0
# Q      8.0   95.000000  29.277002   50.0   87.5  100.0  120.0  120.0
# R      8.0  115.000000  22.677868   90.0  100.0  110.0  120.0  150.0

# %%
#normalmente agrupamos por valores categóricos ou com poucos valores unitários

# %%
df.groupby(["mfr", "type"])["calories"].describe() #subagrupamento
# Out:
#           count        mean        std    min    25%    50%    75%    max
# mfr type
# A   H       1.0  100.000000        NaN  100.0  100.0  100.0  100.0  100.0
# G   C      22.0  111.363636  10.371873  100.0  110.0  110.0  110.0  140.0
# K   C      23.0  108.695652  22.218818   50.0  100.0  110.0  115.0  160.0
# N   C       5.0   84.000000   8.944272   70.0   80.0   90.0   90.0   90.0
#     H       1.0  100.000000        NaN  100.0  100.0  100.0  100.0  100.0
# P   C       9.0  108.888889  10.540926   90.0  100.0  110.0  120.0  120.0
# Q   C       7.0   94.285714  31.547394   50.0   75.0  100.0  120.0  120.0
#     H       1.0  100.000000        NaN  100.0  100.0  100.0  100.0  100.0
# R   C       8.0  115.000000  22.677868   90.0  100.0  110.0  120.0  150.0

# %%
df.groupby(["mfr", "vitamins"])["calories"].describe()
# Out:
#               count        mean        std    min    25%    50%    75%    max
# mfr vitamins
# A   25          1.0  100.000000        NaN  100.0  100.0  100.0  100.0  100.0
# G   25         19.0  110.526316   8.481145  100.0  110.0  110.0  110.0  130.0
#     100         3.0  116.666667  20.816660  100.0  105.0  110.0  125.0  140.0
# K   25         20.0  107.500000  22.682012   50.0  100.0  110.0  112.5  160.0
#     100         3.0  116.666667  20.816660  100.0  105.0  110.0  125.0  140.0
# N   0           4.0   90.000000   8.164966   80.0   87.5   90.0   92.5  100.0
#     25          2.0   80.000000  14.142136   70.0   75.0   80.0   85.0   90.0
# P   25          9.0  108.888889  10.540926   90.0  100.0  110.0  120.0  120.0
# Q   0           4.0   80.000000  35.590261   50.0   50.0   75.0  105.0  120.0
#     25          4.0  110.000000  11.547005  100.0  100.0  110.0  120.0  120.0
# R   25          8.0  115.000000  22.677868   90.0  100.0  110.0  120.0  150.0

# %%
df.groupby(["mfr", "shelf"])["calories"].describe()
# Out:
#            count        mean        std    min    25%    50%    75%    max
# mfr shelf
# A   2        1.0  100.000000        NaN  100.0  100.0  100.0  100.0  100.0
# G   1        6.0  106.666667   5.163978  100.0  102.5  110.0  110.0  110.0
#     2        7.0  111.428571   3.779645  110.0  110.0  110.0  110.0  120.0
#     3        9.0  114.444444  15.092309  100.0  100.0  110.0  130.0  140.0
# K   1        4.0  107.500000   5.000000  100.0  107.5  110.0  110.0  110.0
#     2        7.0  111.428571   6.900656  100.0  110.0  110.0  115.0  120.0
#     3       12.0  107.500000  30.785179   50.0   90.0  110.0  125.0  160.0
# N   1        3.0   86.666667   5.773503   80.0   85.0   90.0   90.0   90.0
#     2        2.0   95.000000   7.071068   90.0   92.5   95.0   97.5  100.0
#     3        1.0   70.000000        NaN   70.0   70.0   70.0   70.0   70.0
# P   1        2.0  105.000000   7.071068  100.0  102.5  105.0  107.5  110.0
# ...

# %% [markdown]
# # Value_counts

# %%
df.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0    5.0       6     280        25      3     1.0  0.33  68.402973
# 1    8.0       8     135         0      3     1.0  1.00  33.983679
# 2    7.0       5     320        25      3     1.0  0.33  59.425505
# 3    8.0       0     330        25      3     1.0  0.50  93.704912
# 4   14.0       8      -1        25      3     1.0  0.75  34.384843

# %%
df.nunique()
# Out:
# name        77
# mfr          7
# type         2
# calories    11
# protein      6
# fat          5
# sodium      27
# fiber       13
# carbo       22
# sugars      17
# potass      36
# vitamins     3
# shelf        3
# weight       7
# cups        12
# rating      77
# dtype: int64

# %%
df["rating"].value_counts()
# Out:
# rating
# 68.402973    1
# 40.692320    1
# 49.511874    1
# 63.005645    1
# 60.756112    1
#             ..
# 31.435973    1
# 32.207582    1
# 44.330856    1
# 36.176196    1
# 36.187559    1
# Name: count, Length: 77, dtype: int64

# %%
df['mfr'].value_counts()
# Out:
# mfr
# K    23
# G    22
# P     9
# Q     8
# R     8
# N     6
# A     1
# Name: count, dtype: int64

# %%
df["rating"].value_counts(bins = 10) #cria intervalos
#vemos que a maioria dos dados está agrupado no intervalo (33.175, 40.741]
# Out:
# (33.175, 40.741]                22
# (25.609, 33.175]                14
# (48.308, 55.874]                12
# (40.741, 48.308]                11
# (17.965999999999998, 25.609]     6
# (55.874, 63.44]                  6
# (63.44, 71.006]                  3
# (71.006, 78.572]                 2
# (86.139, 93.705]                 1
# (78.572, 86.139]                 0
# Name: count, dtype: int64

# %%
df["rating"].value_counts(bins = 10).sort_index()
# Out:
# (17.965999999999998, 25.609]     6
# (25.609, 33.175]                14
# (33.175, 40.741]                22
# (40.741, 48.308]                11
# (48.308, 55.874]                12
# (55.874, 63.44]                  6
# (63.44, 71.006]                  3
# (71.006, 78.572]                 2
# (78.572, 86.139]                 0
# (86.139, 93.705]                 1
# Name: count, dtype: int64

# %%
df["rating"].value_counts(bins = 10, normalize=True).sort_index() #mostra em porcentagem
# Out:
# (17.965999999999998, 25.609]    0.077922
# (25.609, 33.175]                0.181818
# (33.175, 40.741]                0.285714
# (40.741, 48.308]                0.142857
# (48.308, 55.874]                0.155844
# (55.874, 63.44]                 0.077922
# (63.44, 71.006]                 0.038961
# (71.006, 78.572]                0.025974
# (78.572, 86.139]                0.000000
# (86.139, 93.705]                0.012987
# Name: proportion, dtype: float64

# %%
df["rating"].value_counts(bins = 10, normalize = True).sort_index() * 100
# Out:
# (17.965999999999998, 25.609]     7.792208
# (25.609, 33.175]                18.181818
# (33.175, 40.741]                28.571429
# (40.741, 48.308]                14.285714
# (48.308, 55.874]                15.584416
# (55.874, 63.44]                  7.792208
# (63.44, 71.006]                  3.896104
# (71.006, 78.572]                 2.597403
# (78.572, 86.139]                 0.000000
# (86.139, 93.705]                 1.298701
# Name: proportion, dtype: float64

# %%
df["rating"].value_counts(bins = 10, normalize = True).sort_index().mul(100).round(2)
# Out:
# (17.965999999999998, 25.609]     7.79
# (25.609, 33.175]                18.18
# (33.175, 40.741]                28.57
# (40.741, 48.308]                14.29
# (48.308, 55.874]                15.58
# (55.874, 63.44]                  7.79
# (63.44, 71.006]                  3.90
# (71.006, 78.572]                 2.60
# (78.572, 86.139]                 0.00
# (86.139, 93.705]                 1.30
# Name: proportion, dtype: float64

# %% [markdown]
# # Eliminando dados

# %%
df.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0    5.0       6     280        25      3     1.0  0.33  68.402973
# 1    8.0       8     135         0      3     1.0  1.00  33.983679
# 2    7.0       5     320        25      3     1.0  0.33  59.425505
# 3    8.0       0     330        25      3     1.0  0.50  93.704912
# 4   14.0       8      -1        25      3     1.0  0.75  34.384843

# %%
df_sem_type = df.drop(columns = 'type')

# %%
df_sem_type.head()
# Out:
#                         name mfr  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N        70        4    1     130   10.0
# 1          100% Natural Bran   Q       120        3    5      15    2.0
# 2                   All-Bran   K        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K        50        4    0     140   14.0
# 4             Almond Delight   R       110        2    2     200    1.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0    5.0       6     280        25      3     1.0  0.33  68.402973
# 1    8.0       8     135         0      3     1.0  1.00  33.983679
# 2    7.0       5     320        25      3     1.0  0.33  59.425505
# 3    8.0       0     330        25      3     1.0  0.50  93.704912
# 4   14.0       8      -1        25      3     1.0  0.75  34.384843

# %%
df_sem_type.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      77 non-null     object
#  1   mfr       77 non-null     object
#  2   calories  77 non-null     int64
#  3   protein   77 non-null     int64
#  4   fat       77 non-null     int64
#  5   sodium    77 non-null     int64
#  6   fiber     77 non-null     float64
#  7   carbo     77 non-null     float64
#  8   sugars    77 non-null     int64
#  9   potass    77 non-null     int64
#  10  vitamins  77 non-null     int64
#  11  shelf     77 non-null     int64
#  12  weight    77 non-null     float64
#  13  cups      77 non-null     float64
#  14  rating    77 non-null     float64
# dtypes: float64(5), int64(8), object(2)
# memory usage: 9.1+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      77 non-null     object
#  1   mfr       77 non-null     object
#  2   type      77 non-null     object
#  3   calories  77 non-null     int64
#  4   protein   77 non-null     int64
#  5   fat       77 non-null     int64
#  6   sodium    77 non-null     int64
#  7   fiber     77 non-null     float64
#  8   carbo     77 non-null     float64
#  9   sugars    77 non-null     int64
#  10  potass    77 non-null     int64
#  11  vitamins  77 non-null     int64
#  12  shelf     77 non-null     int64
#  13  weight    77 non-null     float64
#  14  cups      77 non-null     float64
#  15  rating    77 non-null     float64
# dtypes: float64(5), int64(8), object(3)
# memory usage: 9.8+ KB

# %%
with pd.option_context("float_format", "{:.2f}".format):
  display(df.describe())
# Out:
#        calories  protein   fat  sodium  fiber  carbo  sugars  potass  \
# count     77.00    77.00 77.00   77.00  77.00  77.00   77.00   77.00
# mean     106.88     2.55  1.01  159.68   2.15  14.60    6.92   96.08
# std       19.48     1.09  1.01   83.83   2.38   4.28    4.44   71.29
# min       50.00     1.00  0.00    0.00   0.00  -1.00   -1.00   -1.00
# 25%      100.00     2.00  0.00  130.00   1.00  12.00    3.00   40.00
# 50%      110.00     3.00  1.00  180.00   2.00  14.00    7.00   90.00
# 75%      110.00     3.00  2.00  210.00   3.00  17.00   11.00  120.00
# max      160.00     6.00  5.00  320.00  14.00  23.00   15.00  330.00
#
#        vitamins  shelf  weight  cups  rating
# count     77.00  77.00   77.00 77.00   77.00
# mean      28.25   2.21    1.03  0.82   42.67
# std       22.34   0.83    0.15  0.23   14.05
# min        0.00   1.00    0.50  0.25   18.04
# 25%       25.00   1.00    1.00  0.67   33.17
# 50%       25.00   2.00    1.00  0.75   40.40
# ...

# %%
df[(df['carbo'] == -1) | (df['sugars'] == -1) | (df['potass'] == -1)]
# Out:
#                       name mfr type  calories  protein  fat  sodium  fiber  \
# 4           Almond Delight   R    C       110        2    2     200    1.0
# 20  Cream of Wheat (Quick)   N    H       100        3    0      80    1.0
# 57          Quaker Oatmeal   Q    H       100        5    2       0    2.7
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 4    14.0       8      -1        25      3     1.0  0.75  34.384843
# 20   21.0       0      -1         0      2     1.0  1.00  64.533816
# 57   -1.0      -1     110         0      1     1.0  0.67  50.828392

# %%
df_sem_negativos = df[(df['carbo'] == -1) | (df['sugars'] == -1) | (df['potass'] == -1)]

df_sem_negativos.head()
# Out:
#                       name mfr type  calories  protein  fat  sodium  fiber  \
# 4           Almond Delight   R    C       110        2    2     200    1.0
# 20  Cream of Wheat (Quick)   N    H       100        3    0      80    1.0
# 57          Quaker Oatmeal   Q    H       100        5    2       0    2.7
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 4    14.0       8      -1        25      3     1.0  0.75  34.384843
# 20   21.0       0      -1         0      2     1.0  1.00  64.533816
# 57   -1.0      -1     110         0      1     1.0  0.67  50.828392

# %%
df_sem_negativos = df[(df['carbo'] != -1) & (df['sugars'] != -1) & (df['potass'] != -1)]

df_sem_negativos.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 5    Apple Cinnamon Cheerios   G    C       110        2    2     180    1.5
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0    5.0       6     280        25      3     1.0  0.33  68.402973
# 1    8.0       8     135         0      3     1.0  1.00  33.983679
# 2    7.0       5     320        25      3     1.0  0.33  59.425505
# 3    8.0       0     330        25      3     1.0  0.50  93.704912
# 5   10.5      10      70        25      1     1.0  0.75  29.509541

# %%
df_sem_negativos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 74 entries, 0 to 76
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      74 non-null     object
#  1   mfr       74 non-null     object
#  2   type      74 non-null     object
#  3   calories  74 non-null     int64
#  4   protein   74 non-null     int64
#  5   fat       74 non-null     int64
#  6   sodium    74 non-null     int64
#  7   fiber     74 non-null     float64
#  8   carbo     74 non-null     float64
#  9   sugars    74 non-null     int64
#  10  potass    74 non-null     int64
#  11  vitamins  74 non-null     int64
#  12  shelf     74 non-null     int64
#  13  weight    74 non-null     float64
#  14  cups      74 non-null     float64
#  15  rating    74 non-null     float64
# dtypes: float64(5), int64(8), object(3)
# memory usage: 9.8+ KB

# %%
df_sem_negativos = df_sem_negativos.reset_index(drop=True)

df_sem_negativos.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4    Apple Cinnamon Cheerios   G    C       110        2    2     180    1.5
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0    5.0       6     280        25      3     1.0  0.33  68.402973
# 1    8.0       8     135         0      3     1.0  1.00  33.983679
# 2    7.0       5     320        25      3     1.0  0.33  59.425505
# 3    8.0       0     330        25      3     1.0  0.50  93.704912
# 4   10.5      10      70        25      1     1.0  0.75  29.509541

# %%
with pd.option_context("float_format", "{:.2f}".format):
  display(df_sem_negativos.describe())
# Out:
#        calories  protein   fat  sodium  fiber  carbo  sugars  potass  \
# count     74.00    74.00 74.00   74.00  74.00  74.00   74.00   74.00
# mean     107.03     2.51  1.00  162.36   2.18  14.73    7.11   98.51
# std       19.84     1.08  1.01   82.77   2.42   3.89    4.36   70.88
# min       50.00     1.00  0.00    0.00   0.00   5.00    0.00   15.00
# 25%      100.00     2.00  0.00  135.00   0.25  12.00    3.00   41.25
# 50%      110.00     2.50  1.00  180.00   2.00  14.50    7.00   90.00
# 75%      110.00     3.00  1.00  217.50   3.00  17.00   11.00  120.00
# max      160.00     6.00  5.00  320.00  14.00  23.00   15.00  330.00
#
#        vitamins  shelf  weight  cups  rating
# count     74.00  74.00   74.00 74.00   74.00
# mean      29.05   2.22    1.03  0.82   42.37
# std       22.29   0.83    0.15  0.24   14.03
# min        0.00   1.00    0.50  0.25   18.04
# 25%       25.00   1.25    1.00  0.67   32.45
# 50%       25.00   2.00    1.00  0.75   40.25
# ...

# %%
df[~((df['carbo'] == -1) | (df['sugars'] == -1) | (df['potass'] == -1))]
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 1           100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 5     Apple Cinnamon Cheerios   G    C       110        2    2     180    1.5
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C       110        2    1     250    0.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 74                 Wheat Chex   R    C       100        3    1     230    3.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# 76        Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
# ...

# %% [markdown]
# # Exportanto dados

# %%
df_sem_negativos.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4    Apple Cinnamon Cheerios   G    C       110        2    2     180    1.5
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0    5.0       6     280        25      3     1.0  0.33  68.402973
# 1    8.0       8     135         0      3     1.0  1.00  33.983679
# 2    7.0       5     320        25      3     1.0  0.33  59.425505
# 3    8.0       0     330        25      3     1.0  0.50  93.704912
# 4   10.5      10      70        25      1     1.0  0.75  29.509541

# %%
with pd.option_context("float_format", "{:.2f}".format):
  display(df_sem_negativos.describe())
# Out:
#        calories  protein   fat  sodium  fiber  carbo  sugars  potass  \
# count     74.00    74.00 74.00   74.00  74.00  74.00   74.00   74.00
# mean     107.03     2.51  1.00  162.36   2.18  14.73    7.11   98.51
# std       19.84     1.08  1.01   82.77   2.42   3.89    4.36   70.88
# min       50.00     1.00  0.00    0.00   0.00   5.00    0.00   15.00
# 25%      100.00     2.00  0.00  135.00   0.25  12.00    3.00   41.25
# 50%      110.00     2.50  1.00  180.00   2.00  14.50    7.00   90.00
# 75%      110.00     3.00  1.00  217.50   3.00  17.00   11.00  120.00
# max      160.00     6.00  5.00  320.00  14.00  23.00   15.00  330.00
#
#        vitamins  shelf  weight  cups  rating
# count     74.00  74.00   74.00 74.00   74.00
# mean      29.05   2.22    1.03  0.82   42.37
# std       22.29   0.83    0.15  0.24   14.03
# min        0.00   1.00    0.50  0.25   18.04
# 25%       25.00   1.25    1.00  0.67   32.45
# 50%       25.00   2.00    1.00  0.75   40.25
# ...

# %%
df_sem_negativos.to_csv('cereal_sem_negativos.csv', index = False)

# %% [markdown]
# # Criando novas colunas

# %%
df["total_carb"] = df['carbo'] + df['sugars']
# Out:
# <ipython-input-147-fabb3ceb7890>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["total_carb"] = df['carbo'] + df['sugars']

# %%
df.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 5    Apple Cinnamon Cheerios   G    C       110        2    2     180    1.5
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating  \
# 0    5.0       6     280        25      3     1.0  0.33  68.402973
# 1    8.0       8     135         0      3     1.0  1.00  33.983679
# 2    7.0       5     320        25      3     1.0  0.33  59.425505
# 3    8.0       0     330        25      3     1.0  0.50  93.704912
# 5   10.5      10      70        25      1     1.0  0.75  29.509541
#
#    total_carb  weight_grams
# 0        11.0       28.3495
# 1        16.0       28.3495
# ...

# %%
df['weight_grams'] = df['weight'] * 28.3495

df.head()
# Out:
# <ipython-input-149-4d2b719f7a1a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['weight_grams'] = df['weight'] * 28.3495
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 5    Apple Cinnamon Cheerios   G    C       110        2    2     180    1.5
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating  \
# 0    5.0       6     280        25      3     1.0  0.33  68.402973
# ...

# %%
with pd.option_context("float_format", "{:.2f}".format):
  display(df.describe())
# Out:
#        calories  protein   fat  sodium  fiber  carbo  sugars  potass  \
# count     74.00    74.00 74.00   74.00  74.00  74.00   74.00   74.00
# mean     107.03     2.51  1.00  162.36   2.18  14.73    7.11   98.51
# std       19.84     1.08  1.01   82.77   2.42   3.89    4.36   70.88
# min       50.00     1.00  0.00    0.00   0.00   5.00    0.00   15.00
# 25%      100.00     2.00  0.00  135.00   0.25  12.00    3.00   41.25
# 50%      110.00     2.50  1.00  180.00   2.00  14.50    7.00   90.00
# 75%      110.00     3.00  1.00  217.50   3.00  17.00   11.00  120.00
# max      160.00     6.00  5.00  320.00  14.00  23.00   15.00  330.00
#
#        vitamins  shelf  weight  cups  rating  total_carb  weight_grams
# count     74.00  74.00   74.00 74.00   74.00       74.00         74.00
# mean      29.05   2.22    1.03  0.82   42.37       21.84         29.22
# std       22.29   0.83    0.15  0.24   14.03        4.34          4.35
# ...

# %% [markdown]
# # Gráficos

# %%
df.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 5    Apple Cinnamon Cheerios   G    C       110        2    2     180    1.5
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating  \
# 0    5.0       6     280        25      3     1.0  0.33  68.402973
# 1    8.0       8     135         0      3     1.0  1.00  33.983679
# 2    7.0       5     320        25      3     1.0  0.33  59.425505
# 3    8.0       0     330        25      3     1.0  0.50  93.704912
# 5   10.5      10      70        25      1     1.0  0.75  29.509541
#
#    total_carb  weight_grams
# 0        11.0       28.3495
# 1        16.0       28.3495
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 74 entries, 0 to 76
# Data columns (total 18 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          74 non-null     object
#  1   mfr           74 non-null     object
#  2   type          74 non-null     object
#  3   calories      74 non-null     int64
#  4   protein       74 non-null     int64
#  5   fat           74 non-null     int64
#  6   sodium        74 non-null     int64
#  7   fiber         74 non-null     float64
#  8   carbo         74 non-null     float64
#  9   sugars        74 non-null     int64
#  10  potass        74 non-null     int64
#  11  vitamins      74 non-null     int64
#  12  shelf         74 non-null     int64
#  13  weight        74 non-null     float64
#  14  cups          74 non-null     float64
#  15  rating        74 non-null     float64
#  16  total_carb    74 non-null     float64
#  17  weight_grams  74 non-null     float64
# ...

# %%
df["mfr"].value_counts()
# Out:
# mfr
# K    23
# G    22
# P     9
# Q     7
# R     7
# N     5
# A     1
# Name: count, dtype: int64

# %%
df["mfr"].value_counts().plot(kind = "bar")
# Out:
# <Axes: xlabel='mfr'>

# %%
df["mfr"].value_counts().plot(
    kind = "bar",
    xlabel= "Fabricante",
    ylabel = "Quantidade",
    title = "Contagem de cereais por fabricante"
)
# Out:
# <Axes: title={'center': 'Contagem de cereais por fabricante'}, xlabel='Fabricante', ylabel='Quantidade'>

# %%
df["mfr"].value_counts().plot(
    kind = "pie",
    ylabel = "Quantidade",
    autopct = "%.1f%%",
    title = "Percentual por fabricante"
)
# Out:
# <Axes: title={'center': 'Percentual por fabricante'}, ylabel='Quantidade'>

# %%
df.groupby("mfr")['calories'].mean().plot(
    kind = "bar",
    xlabel = "Fabricante",
    ylabel = "Calorias",
    title = "Média de calorias por fabricante"
)
# Out:
# <Axes: title={'center': 'Média de calorias por fabricante'}, xlabel='Fabricante', ylabel='Calorias'>

# %%
df.groupby("mfr")['calories'].mean().plot(
    kind = "line",
    xlabel = "Fabricante",
    ylabel = "Calorias",
    title = "Média de calorias por fabricante"
)
# Out:
# <Axes: title={'center': 'Média de calorias por fabricante'}, xlabel='Fabricante', ylabel='Calorias'>

# %% [markdown]
# # Interagindo com planilhas

# %%
df2 = pd.read_excel('reshaping.xlsx')

df2
# Out:
#    Estudante Categoria  Semana          Tópico  Nota
# 0      Maria    Testes       1       1. Python   100
# 1      Maria   Projeto       1       1. Python   100
# 2      Maria    Testes       1       2. GitHub    70
# 3      Maria   Projeto       1       2. GitHub    70
# 4      Maria    Testes       2   3. Matplotlib    80
# 5      Maria   Projeto       2   3. Matplotlib    70
# 6      Maria    Testes       2          4. SQL    80
# 7      Maria   Projeto       2          4. SQL    70
# 8      Maria    Testes       3        5. NumPy    60
# 9      Maria   Projeto       3        5. NumPy    60
# 10     Maria    Testes       3          6. POO    90
# 11     Maria   Projeto       3          6. POO    80
# 12     Maria    Testes       4       7. Pandas    70
# 13     Maria   Projeto       4       7. Pandas    70
# 14     Maria    Testes       4  8. Estatística    80
# 15     Maria   Projeto       4  8. Estatística    80
# 16      João    Testes       1       1. Python   100
# ...

# %%
#operação Pivot -> reorganiza os dados

# %%
df_pivot = df2.pivot(
    index = ['Estudante'],
    columns = ["Categoria", 'Semana', 'Tópico'],
    values = "Nota"
)

df_pivot
# Out:
# Categoria    Testes   Projeto    Testes   Projeto        Testes       Projeto  \
# Semana            1         1         1         1             2             2
# Tópico    1. Python 1. Python 2. GitHub 2. GitHub 3. Matplotlib 3. Matplotlib
# Estudante
# João            100        80        90        90            60            70
# Maria           100       100        70        70            80            70
#
# Categoria Testes Projeto   Testes  Projeto Testes Projeto    Testes   Projeto  \
# Semana         2       2        3        3      3       3         4         4
# Tópico    4. SQL  4. SQL 5. NumPy 5. NumPy 6. POO  6. POO 7. Pandas 7. Pandas
# Estudante
# João          70      80       80       90     70      80        70       100
# Maria         80      70       60       60     90      80        70        70
#
# Categoria         Testes        Projeto
# Semana                 4              4
# Tópico    8. Estatística 8. Estatística
# Estudante
# ...
